# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2025.4.26)

# %%
import json
import requests
import os
from urllib.parse import urlparse
import time
import random

# --- 설정값 ---
FILE_PATH = 'games.json'  # ⚠️ JSON 파일 경로를 실제 파일 이름으로 변경하세요.
BASE_DOWNLOAD_DIR = r'D:\ML\DS'
MAX_FILES_PER_GENRE = 15000
TARGET_TAGS = [
    "Adventure", "Action", "RPG", "Strategy", "Simulation", "Sports", "Racing", 
    "Puzzle", "Sandbox", "Shooter", "Survival", "Fighting", "Music"
]
# ----------------

def clean_filename(url):
    """URL에서 안전한 파일 이름을 추출하고 확장자를 포함합니다."""
    path = urlparse(url).path
    filename = os.path.basename(path)
    # 쿼리 파라미터나 기타 불필요한 문자를 제거하고 안전하게 만듭니다.
    if '?' in filename:
        filename = filename.split('?')[0]
    return filename

def get_genre_file_count(genre_dir):
    """장르 폴더 내의 실제 파일 개수를 계산합니다."""
    if not os.path.exists(genre_dir):
        return 0
    # .DS_Store 같은 숨김 파일을 제외하고 파일 개수를 셉니다.
    return len([name for name in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, name)) and not name.startswith('.')])

def manage_file_limit(genre_dir, max_limit):
    """폴더의 파일 수가 최대 한도를 초과할 경우 파일을 랜덤하게 삭제합니다."""
    current_count = get_genre_file_count(genre_dir)
    if current_count > max_limit:
        files_to_delete = current_count - max_limit
        all_files = [f for f in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, f)) and not f.startswith('.')]
        
        # 삭제할 파일을 랜덤하게 선택
        files_to_remove = random.sample(all_files, files_to_delete)
        
        print(f"[{os.path.basename(genre_dir)}] ❗️ 파일 초과: {current_count}개. {files_to_delete}개 삭제 중...")
        
        for file in files_to_remove:
            try:
                os.remove(os.path.join(genre_dir, file))
            except OSError as e:
                print(f"파일 삭제 오류: {e}")

def download_screenshot(url, genre_folder, appid):
    """스크린샷을 다운로드하고 장르 폴더에 저장합니다."""
    
    # 파일명 생성: AppID와 원래 파일명을 조합하여 중복 방지 및 추적 용이
    original_filename = clean_filename(url)
    filename = f"{appid}_{original_filename}"
    save_path = os.path.join(genre_folder, filename)

    if os.path.exists(save_path):
        # 파일이 이미 존재하면 건너뜁니다.
        # print(f"파일이 이미 존재하여 건너뜁니다: {filename}")
        return True

    try:
        # 파일 다운로드 (스트리밍 사용)
        response = requests.get(url, stream=True, timeout=10)
        response.raise_for_status() # HTTP 오류가 발생하면 예외 발생

        with open(save_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    
    except requests.exceptions.RequestException as e:
        # print(f"다운로드 실패 ({url}): {e}")
        return False

def process_game_data(file_path):
    """JSON 파일을 읽고 지정된 태그별로 스크린샷을 다운로드합니다."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"❌ 오류: 파일을 찾을 수 없습니다. 경로를 확인해 주세요: {file_path}")
        return
    except json.JSONDecodeError:
        print("❌ 오류: JSON 파일 형식이 올바르지 않습니다.")
        return
    
    # 기본 다운로드 디렉토리 생성
    os.makedirs(BASE_DOWNLOAD_DIR, exist_ok=True)
    
    # 장르별 폴더 생성 및 현재 파일 개수 추적
    genre_dirs = {}
    
    for tag in TARGET_TAGS:
        genre_path = os.path.join(BASE_DOWNLOAD_DIR, tag)
        os.makedirs(genre_path, exist_ok=True)
        genre_dirs[tag] = genre_path
        # 초기 파일 개수를 계산하여 MAX_FILES_PER_GENRE를 초과하는지 확인하고 관리합니다.
        manage_file_limit(genre_path, MAX_FILES_PER_GENRE)

    # 전체 데이터 순회 (딕셔너리 구조: {AppID: {게임 데이터}})
    game_list = data.values() if isinstance(data, dict) else data
    
    total_downloads = 0
    
    print("-" * 50)
    print(f"총 {len(game_list)}개의 게임을 처리합니다.")
    print(f"대상 태그: {', '.join(TARGET_TAGS)}")
    print(f"장르별 최대 파일 수: {MAX_FILES_PER_GENRE}개")
    print("-" * 50)

    for appid, game in data.items():
        if not isinstance(game, dict):
            continue
            
        # --------------------------------------------------------------------
        # 🛠️ 오류 수정 부분: 'tags' 키의 값을 가져와 형태에 따라 처리
        tags_data = game.get('tags')
        
        if isinstance(tags_data, dict):
            # 딕셔너리 형태일 경우 (기존 방식)
            game_tags = set(tags_data.keys())
        elif isinstance(tags_data, list):
            # 리스트 형태일 경우 (현재 오류 발생 형태)
            game_tags = set(tags_data)
        else:
            # tags 키가 없거나 다른 형태일 경우 건너뜁니다.
            continue
        # --------------------------------------------------------------------
            
        # 대상 태그와 게임 태그의 교집합을 구합니다.
        matching_tags = game_tags.intersection(TARGET_TAGS)
        
        # 일치하는 태그가 없는 경우 건너뜁니다.
        if not matching_tags:
            continue
            
        # 스크린샷 URL 목록 가져오기
        screenshots = game.get('screenshots', [])
        
        if not screenshots:
            continue
            
        print(f"[{game.get('name', appid)}] - {len(screenshots)}개 스크린샷, 매칭 태그: {', '.join(matching_tags)}")

        # 매칭된 각 태그에 대해 스크린샷을 저장합니다. (중복 저장 허용)
        for tag in matching_tags:
            genre_dir = genre_dirs[tag]
            
            # 파일 개수 확인: 이미 초과한 상태라면 다운로드 건너뛰기
            current_count = get_genre_file_count(genre_dir)
            if current_count >= MAX_FILES_PER_GENRE:
                # print(f"[{tag}] 🛑 최대 파일 수 ({MAX_FILES_PER_GENRE})에 도달하여 건너뜁니다.")
                continue

            # 스크린샷 다운로드 시작
            for shot in screenshots:
                if current_count >= MAX_FILES_PER_GENRE:
                    # 다운로드 도중에 한도를 초과하면 나머지 스크린샷은 건너뜁니다.
                    # print(f"[{tag}] 🛑 다운로드 중 한도 초과. 다음 태그로 이동.")
                    break
                
                # --------------------------------------------------------------------
                # 🛠️ 오류 수정 부분: 'shot'이 문자열인지 딕셔너리인지 확인하고 URL을 가져옵니다.
                if isinstance(shot, str):
                    # shot이 이미 URL 문자열인 경우
                    screenshot_url = shot
                elif isinstance(shot, dict):
                    # shot이 딕셔너리인 경우 (기존 코드)
                    screenshot_url = shot.get('path_full')
                else:
                    # 예상치 못한 형식인 경우 건너뜁니다.
                    continue
                # --------------------------------------------------------------------

                if screenshot_url:
                    if download_screenshot(screenshot_url, genre_dir, appid):
                        total_downloads += 1
                        current_count += 1
                        # 100개 다운로드마다 진행 상황을 출력합니다.
                        if total_downloads % 100 == 0:
                            print(f"--- 총 다운로드 수: {total_downloads}개 ---")
                        
            # 다운로드가 완료된 후, 혹시 모를 초과 상황을 대비하여 다시 파일 제한을 관리합니다.
            manage_file_limit(genre_dir, MAX_FILES_PER_GENRE)

    print("-" * 50)
    print(f"✅ 모든 게임 처리가 완료되었습니다. 총 {total_downloads}개의 파일이 저장되었습니다.")
    print(f"폴더 위치: {os.path.abspath(BASE_DOWNLOAD_DIR)}")
    print("-" * 50)

# 실행
process_game_data(FILE_PATH)
# Out:
# --------------------------------------------------
# 총 111452개의 게임을 처리합니다.
# 대상 태그: Adventure, RPG, Strategy, Simulation, Sports, Racing, Puzzle, Sandbox, Shooter, Survival, Fighting, Music
# 장르별 최대 파일 수: 15000개
# --------------------------------------------------
# [Galactic Bowling] - 10개 스크린샷, 매칭 태그: Sports
# [Henosis™] - 7개 스크린샷, 매칭 태그: Survival, Adventure, Puzzle
# [Two Weeks in Painland] - 24개 스크린샷, 매칭 태그: Adventure
# [Wartune Reborn] - 12개 스크린샷, 매칭 태그: RPG, Strategy
# [TD Worlds] - 12개 스크린샷, 매칭 태그: Strategy
# [MazM: Jekyll and Hyde] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Strategy
# --- 총 다운로드 수: 100개 ---
# [Deadlings: Rotten Edition] - 10개 스크린샷, 매칭 태그: Adventure
# [WARSAW] - 8개 스크린샷, 매칭 태그: RPG, Strategy
# [Cthulhu Realms] - 6개 스크린샷, 매칭 태그: Strategy
# [Clockwork Dungeon] - 5개 스크린샷, 매칭 태그: Puzzle
# [Diary of Lucie] - 12개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Alien Breed 3: Descent] - 10개 스크린샷, 매칭 태그: Shooter
# [Hunting Unlimited 3] - 6개 스크린샷, 매칭 태그: Sports, Simulation
# --- 총 다운로드 수: 200개 ---
# [Hero of the Kingdom II] - 9개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [KHIO] - 5개 스크린샷, 매칭 태그: Survival, Adventure, Puzzle
# [Steam Squad] - 37개 스크린샷, 매칭 태그: Strategy
# [Project: R.E.B.O.O.T 2] - 6개 스크린샷, 매칭 태그: Adventure
# [Aerofly FS 2 Flight Simulator] - 27개 스크린샷, 매칭 태그: Simulation, Racing
# --- 총 다운로드 수: 300개 ---
# [Turtle Lu] - 5개 스크린샷, 매칭 태그: Adventure
# [Kanjozoku Game レーサー] - 14개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# [PowersVR] - 5개 스크린샷, 매칭 태그: Simulation
# [Pathfinders: Memories] - 12개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 400개 ---
# [Bright Days in Quarantine] - 5개 스크린샷, 매칭 태그: Simulation
# [Terror In The Atomic Desert] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Unhappy Ever After] - 19개 스크린샷, 매칭 태그: Adventure, RPG
# [March Of Soldiers] - 12개 스크린샷, 매칭 태그: Strategy
# [Bepuzzled Kittens Jigsaw Puzzle] - 6개 스크린샷, 매칭 태그: Puzzle
# [Dream Detective] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 500개 ---
# [Tower of Shades] - 9개 스크린샷, 매칭 태그: RPG
# [Vanguard Princess] - 5개 스크린샷, 매칭 태그: Fighting
# [IRON REBELLION] - 5개 스크린샷, 매칭 태그: Shooter, Simulation, Strategy
# [Treasures of the Ancients: Egypt] - 6개 스크린샷, 매칭 태그: Adventure
# [Deadfall Adventures] - 20개 스크린샷, 매칭 태그: Adventure, Strategy, Survival, Puzzle, Shooter
# --- 총 다운로드 수: 600개 ---
# [Reigns: Game of Thrones] - 10개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [CasinoRPG] - 9개 스크린샷, 매칭 태그: Simulation, RPG
# [Fuyu no Tsuma] - 6개 스크린샷, 매칭 태그: Adventure, Shooter, Puzzle
# --- 총 다운로드 수: 700개 ---
# [Far Cry® 5] - 16개 스크린샷, 매칭 태그: Survival, Adventure, Shooter
# [Loot Collection: Mahjong] - 17개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle, Strategy
# --- 총 다운로드 수: 800개 ---
# [INFERNO CLIMBER] - 16개 스크린샷, 매칭 태그: Survival, RPG
# [Grim Tales: The Heir Collector's Edition] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Mythos Ever After: A Cthulhu Dating Sim] - 5개 스크린샷, 매칭 태그: Adventure
# [A Journey Through Valhalla] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [COUNTDOWN] - 12개 스크린샷, 매칭 태그: Survival, Strategy
# --- 총 다운로드 수: 900개 ---
# [Colours of Magic: Aqua Teeter] - 5개 스크린샷, 매칭 태그: Puzzle
# [Forza Horizon 4] - 13개 스크린샷, 매칭 태그: Sports, Adventure, Simulation, Racing
# [Viking Warrior] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Square Keeper] - 8개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Slipstream 5000] - 12개 스크린샷, 매칭 태그: Sports, Racing
# --- 총 다운로드 수: 1000개 ---
# [100 Doors: Escape from Work] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Project MIKHAIL: A Muv-Luv War Story] - 11개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Strategy
# [Rezist: Tower Defense] - 7개 스크린샷, 매칭 태그: Strategy
# [Max Payne] - 15개 스크린샷, 매칭 태그: Adventure, Shooter
# --- 총 다운로드 수: 1100개 ---
# [Black Mansion] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Mirrorama] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Carrier Battles 4 Guadalcanal - Pacific War Naval Warfare] - 44개 스크린샷, 매칭 태그: Simulation, Strategy
# --- 총 다운로드 수: 1200개 ---
# [Sally Face - Episode One] - 33개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 1300개 ---
# [Crimson Spires] - 5개 스크린샷, 매칭 태그: Adventure
# [Endline] - 5개 스크린샷, 매칭 태그: Shooter
# [Realms VR] - 36개 스크린샷, 매칭 태그: Sports, Puzzle, Racing, Shooter
# --- 총 다운로드 수: 1400개 ---
# [AmazeD 3D] - 6개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [The Warrior Of Treasures] - 6개 스크린샷, 매칭 태그: Adventure
# [Red Crow Mysteries: Legion] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 1500개 ---
# [四国志でらっくす ～酒池肉うどん戦記～] - 16개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Crazy Critters - Combat Cats] - 7개 스크린샷, 매칭 태그: Shooter, Fighting
# [The Adventures of Jason and the Argonauts] - 6개 스크린샷, 매칭 태그: Strategy
# [Halloween Puzzles] - 12개 스크린샷, 매칭 태그: Sports, Adventure, Strategy, Simulation, Puzzle
# --- 총 다운로드 수: 1600개 ---
# [I Walk Among Zombies Vol. 3] - 8개 스크린샷, 매칭 태그: Adventure
# [Escape From School] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Aurion: Legacy of the Kori-Odan] - 8개 스크린샷, 매칭 태그: Adventure, RPG
# [Superola Champion Edition] - 8개 스크린샷, 매칭 태그: Adventure
# [Teleporter: World of Gamers (Alpha)] - 17개 스크린샷, 매칭 태그: Simulation, RPG
# --- 총 다운로드 수: 1700개 ---
# [Automobilista 2] - 21개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# [Marching Simulator] - 4개 스크린샷, 매칭 태그: Simulation
# [Oxygen Not Included] - 8개 스크린샷, 매칭 태그: Adventure, Strategy, Survival, Simulation, Sandbox
# --- 총 다운로드 수: 1800개 ---
# [Laruaville 10 Match 3 Puzzle] - 8개 스크린샷, 매칭 태그: Puzzle
# [Slot Shots Pinball Collection] - 20개 스크린샷, 매칭 태그: Sports
# [Laid-Back Camp - Virtual - Lake Motosu] - 10개 스크린샷, 매칭 태그: Adventure
# [Kor] - 12개 스크린샷, 매칭 태그: Adventure, RPG
# [Bighead Runner] - 6개 스크린샷, 매칭 태그: Adventure, Music
# [TowerClimb] - 12개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 1900개 ---
# [Mission Ammunition] - 6개 스크린샷, 매칭 태그: Shooter
# [The Glow] - 6개 스크린샷, 매칭 태그: Survival, RPG, Strategy
# [Fat City] - 5개 스크린샷, 매칭 태그: Strategy
# [Dark Eden] - 5개 스크린샷, 매칭 태그: RPG
# [Hex: Origins] - 5개 스크린샷, 매칭 태그: Puzzle
# [ANARCHY] - 15개 스크린샷, 매칭 태그: Adventure, Fighting, Shooter
# --- 총 다운로드 수: 2000개 ---
# [Dark Throne] - 13개 스크린샷, 매칭 태그: Adventure, RPG
# [Puyo Puyo™Tetris®] - 10개 스크린샷, 매칭 태그: Puzzle, Fighting
# [Numba Deluxe] - 10개 스크린샷, 매칭 태그: Puzzle
# [Pickup One] - 5개 스크린샷, 매칭 태그: Racing
# [DYNASTY WARRIORS 9] - 6개 스크린샷, 매칭 태그: Adventure, RPG
# [The Chaos Engine] - 6개 스크린샷, 매칭 태그: Shooter
# [Domino House] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Ragnarock] - 14개 스크린샷, 매칭 태그: Sports, Music, Racing
# --- 총 다운로드 수: 2100개 ---
# [Into the Void] - 9개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [10 Second Ninja X] - 10개 스크린샷, 매칭 태그: Puzzle
# [咕啾！文鸟恋爱物语 Love Story of Sparrow] - 5개 스크린샷, 매칭 태그: Adventure
# [Critical Gravity] - 7개 스크린샷, 매칭 태그: Sports, Simulation, Racing, Strategy
# --- 총 다운로드 수: 2200개 ---
# [Go For Launch: Mercury] - 8개 스크린샷, 매칭 태그: Simulation
# [ARENA 8] - 5개 스크린샷, 매칭 태그: Shooter
# [Furries & Scalies: Friendswood] - 5개 스크린샷, 매칭 태그: Adventure, Strategy
# [DEVOUR] - 15개 스크린샷, 매칭 태그: Survival, Puzzle
# [Doug Flutie's Maximum Football 2020] - 11개 스크린샷, 매칭 태그: Sports, Sandbox, Simulation
# [Life In Yima / 依玛村生活] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 2300개 ---
# [Chicken Bomb] - 7개 스크린샷, 매칭 태그: Adventure, RPG
# [Welcome To... Chichester 2 - Part II : No Extra Regrets For The Future] - 12개 스크린샷, 매칭 태그: Adventure
# [Super Soccer Blast] - 7개 스크린샷, 매칭 태그: Sports
# [PuzzGun] - 5개 스크린샷, 매칭 태그: Puzzle
# [Call of Duty® 4: Modern Warfare®] - 14개 스크린샷, 매칭 태그: Shooter
# [Santa's vacation] - 6개 스크린샷, 매칭 태그: Adventure, RPG
# [The Fan] - 10개 스크린샷, 매칭 태그: Adventure
# [Misha Adventures] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Mosaics Galore] - 6개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 2400개 ---
# [Kingdom: The Far Reaches] - 12개 스크린샷, 매칭 태그: Adventure, RPG
# [Yoli TD] - 7개 스크린샷, 매칭 태그: Shooter
# [Merek's Market] - 8개 스크린샷, 매칭 태그: Simulation
# [Kooring VR Coding Adventure] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [Aliens vs. Ghosts] - 12개 스크린샷, 매칭 태그: Shooter
# [伏雨录：少年篇] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 2500개 ---
# [Magical Star Pillars] - 11개 스크린샷, 매칭 태그: Adventure
# [Biathlon Battle VR] - 7개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# [Bigfoot Forest] - 7개 스크린샷, 매칭 태그: Survival, Adventure
# [Journey] - 7개 스크린샷, 매칭 태그: Adventure, Music
# [The Pointless Car Chase: Refueled] - 23개 스크린샷, 매칭 태그: Survival, Adventure, Racing
# --- 총 다운로드 수: 2600개 ---
# [Girlfriend Cards] - 6개 스크린샷, 매칭 태그: Sports, Adventure, Strategy, Simulation, RPG, Puzzle
# [Vetrix] - 6개 스크린샷, 매칭 태그: Puzzle
# [Ultra Foodmess] - 11개 스크린샷, 매칭 태그: Survival
# [Keeplanet] - 6개 스크린샷, 매칭 태그: Simulation
# [One Last Day] - 14개 스크린샷, 매칭 태그: Sandbox, Adventure, Survival
# --- 총 다운로드 수: 2700개 ---
# [CHANGE: A Homeless Survival Experience] - 10개 스크린샷, 매칭 태그: Survival, Simulation, RPG, Strategy
# [天下镖局] - 17개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# --- 총 다운로드 수: 2800개 ---
# [Destructions] - 8개 스크린샷, 매칭 태그: Sandbox, Shooter
# [Penkura] - 14개 스크린샷, 매칭 태그: Survival, Adventure, RPG, Strategy
# [KarmaCrown] - 5개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 2900개 ---
# [Virtual Families 2: Our Dream House] - 5개 스크린샷, 매칭 태그: Simulation
# [Earth Marines] - 7개 스크린샷, 매칭 태그: Adventure, Shooter
# [Mystika 4 : Dark Omens] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Hyperbolic Ignition] - 7개 스크린샷, 매칭 태그: Shooter, Simulation
# [Third Rule of Universe.] - 5개 스크린샷, 매칭 태그: RPG
# [Slime Sports] - 11개 스크린샷, 매칭 태그: Sports
# [Twilight Drive] - 5개 스크린샷, 매칭 태그: Music, Racing
# [Worbital] - 12개 스크린샷, 매칭 태그: Strategy
# [Silver Chains] - 6개 스크린샷, 매칭 태그: Survival, Adventure, Puzzle
# [Neon Noodles - Cyberpunk Kitchen Automation] - 6개 스크린샷, 매칭 태그: Sandbox, Puzzle, Simulation, Strategy
# --- 총 다운로드 수: 3000개 ---
# [Floors of Discomfort] - 6개 스크린샷, 매칭 태그: RPG
# [New Yankee in Santa's Service] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [Twin Synth] - 7개 스크린샷, 매칭 태그: Music
# [Blocky Ball] - 7개 스크린샷, 매칭 태그: Sports, Strategy
# [Minds Eyes] - 6개 스크린샷, 매칭 태그: Adventure
# [To Save Humanity From Virus] - 10개 스크린샷, 매칭 태그: Sandbox, Adventure, Simulation, Strategy
# --- 총 다운로드 수: 3100개 ---
# [The Legend of Heroes: Trails of Cold Steel II] - 8개 스크린샷, 매칭 태그: Adventure, RPG
# [Aoki Ookami to Shiroki Mejika] - 5개 스크린샷, 매칭 태그: Strategy
# [BrainTeaser] - 5개 스크린샷, 매칭 태그: Puzzle
# [Damage: Sadistic Butchering of Humanity] - 5개 스크린샷, 매칭 태그: Adventure
# [Just Get Through] - 17개 스크린샷, 매칭 태그: Sandbox, Adventure, Racing, Puzzle
# --- 총 다운로드 수: 3200개 ---
# [Shape] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Bad birthday] - 6개 스크린샷, 매칭 태그: Adventure
# [Orbital Combat] - 5개 스크린샷, 매칭 태그: Strategy
# [Survival Quiz CITY] - 16개 스크린샷, 매칭 태그: Survival
# [Space Tycoon | 星际大亨] - 10개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Fables of Talumos] - 17개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 3300개 ---
# [Afterlife VR] - 19개 스크린샷, 매칭 태그: Survival, Adventure, Fighting, Puzzle
# [R.E.A.C.T] - 6개 스크린샷, 매칭 태그: Sports
# [Cat Saves Halloween] - 7개 스크린샷, 매칭 태그: Sandbox, Adventure, Simulation
# --- 총 다운로드 수: 3400개 ---
# [Hentai Case Opening] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation
# [Valhalla Hills] - 12개 스크린샷, 매칭 태그: Simulation, Strategy
# [Geo] - 16개 스크린샷, 매칭 태그: Adventure, Simulation
# [Monster Energy Supercross - The Official Videogame 3] - 10개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# --- 총 다운로드 수: 3500개 ---
# [Silver Creek Falls: Chapter 2] - 5개 스크린샷, 매칭 태그: Adventure
# [Gripper's Adventure] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [IN-VERT: Definitive Edition] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Hare] - 5개 스크린샷, 매칭 태그: Racing
# [Star Escape] - 16개 스크린샷, 매칭 태그: Racing
# [Airport Firefighters - The Simulation] - 11개 스크린샷, 매칭 태그: Simulation
# [Frisbros] - 7개 스크린샷, 매칭 태그: Sports, Adventure, Puzzle
# --- 총 다운로드 수: 3600개 ---
# [Crazy Mafioso] - 7개 스크린샷, 매칭 태그: Survival, Shooter
# [Anime Studio Tycoon] - 11개 스크린샷, 매칭 태그: Sandbox, Simulation, Strategy
# [Bunny Battle Arena] - 13개 스크린샷, 매칭 태그: Adventure
# [Honey Rose: Underdog Fighter Extraordinaire] - 14개 스크린샷, 매칭 태그: Adventure, Strategy
# [Ships 2017] - 21개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# --- 총 다운로드 수: 3700개 ---
# [FORECLOSED] - 12개 스크린샷, 매칭 태그: Adventure
# [The Great Jitters: Pudding Panic] - 5개 스크린샷, 매칭 태그: Puzzle, Strategy
# [メンヘラフレシア　フラワリングアビス] - 6개 스크린샷, 매칭 태그: Adventure
# [Draw Slasher] - 6개 스크린샷, 매칭 태그: Adventure, Fighting
# [Toilet Tycoon] - 6개 스크린샷, 매칭 태그: Simulation
# [One Night Stand] - 10개 스크린샷, 매칭 태그: Adventure, Simulation
# --- 총 다운로드 수: 3800개 ---
# [Cryptocracy] - 7개 스크린샷, 매칭 태그: Strategy
# [Bouncing Traveler] - 6개 스크린샷, 매칭 태그: Adventure, Simulation
# [Tales of Cosmos] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Jack Lumber] - 7개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Clazer] - 10개 스크린샷, 매칭 태그: Sports, Simulation
# [crazy maze ~疯狂迷宫 ~ 狂った迷路 ~ Laberinto loco ~ Labyrinthe fou ~ Verrücktes Labyrinth] - 18개 스크린샷, 매칭 태그: Adventure, Strategy
# --- 총 다운로드 수: 3900개 ---
# [Shining Resonance Refrain] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [古剑奇谭二(GuJian2)] - 6개 스크린샷, 매칭 태그: RPG
# [Little Walker] - 8개 스크린샷, 매칭 태그: Adventure
# [Dino Dawn] - 5개 스크린샷, 매칭 태그: Adventure
# [Surface: Return to Another World Collector's Edition] - 9개 스크린샷, 매칭 태그: Adventure
# [Realpolitiks] - 15개 스크린샷, 매칭 태그: Simulation, Strategy
# [Powargrid] - 9개 스크린샷, 매칭 태그: Strategy
# [Xpand Rally] - 8개 스크린샷, 매칭 태그: Racing
# --- 총 다운로드 수: 4000개 ---
# [Isorropia] - 5개 스크린샷, 매칭 태그: Strategy
# [Khimera: Puzzle Island] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Ultra Hat Dimension] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Hard Time] - 14개 스크린샷, 매칭 태그: Adventure, Simulation, RPG
# [Romance of the Three Kingdoms III] - 5개 스크린샷, 매칭 태그: Strategy
# [NETABOKU -A robot girl changes my life as a bedridden boy-] - 5개 스크린샷, 매칭 태그: Adventure
# [Ticket to Ride] - 6개 스크린샷, 매칭 태그: Strategy
# [Train Harder] - 9개 스크린샷, 매칭 태그: Sports
# --- 총 다운로드 수: 4100개 ---
# [HUMBLE ZOMBIE] - 14개 스크린샷, 매칭 태그: Simulation
# [Sally's Salon: Kiss & Make-Up] - 20개 스크린샷, 매칭 태그: Adventure, Strategy
# [while True: learn()] - 21개 스크린샷, 매칭 태그: Sandbox, Puzzle, Simulation
# --- 총 다운로드 수: 4200개 ---
# [Fight N' Fall] - 7개 스크린샷, 매칭 태그: Fighting
# [The Adventures of Mr. Hat] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Murasaki] - 9개 스크린샷, 매칭 태그: Puzzle
# [Jelly Killer] - 5개 스크린샷, 매칭 태그: Adventure
# [Tactics V: "Obsidian Brigade"] - 7개 스크린샷, 매칭 태그: RPG, Strategy
# [Mystery Case Files: Ravenhearst®] - 3개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Choice of the Star Captain] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Adventure of Great Wolf] - 5개 스크린샷, 매칭 태그: Adventure
# [My Cashy Side Job at Lost&Found in the Subway of Million-Person City] - 5개 스크린샷, 매칭 태그: Adventure
# [TURGUL: RAPID FIGHTING] - 10개 스크린샷, 매칭 태그: Sports, Adventure, RPG
# --- 총 다운로드 수: 4300개 ---
# [Lost in Blindness] - 5개 스크린샷, 매칭 태그: Adventure
# [Anchorhead] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Scikor - Final Scale] - 14개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Trekking and Camping | 远足与露营] - 6개 스크린샷, 매칭 태그: Adventure
# [Spark and The Digital Daydream] - 6개 스크린샷, 매칭 태그: Adventure
# [Google Spotlight Stories: Special Delivery] - 5개 스크린샷, 매칭 태그: Adventure
# [Memory Note] - 5개 스크린샷, 매칭 태그: Adventure
# [Switchball HD - Puzzle Platformer] - 11개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle
# --- 총 다운로드 수: 4400개 ---
# [Beyond Senses] - 11개 스크린샷, 매칭 태그: Survival, Adventure, Strategy
# [Viking Saga: New World] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Buried Alive: The Annihilation VR] - 9개 스크린샷, 매칭 태그: Adventure, Simulation, Shooter
# [Sunset fighter] - 5개 스크린샷, 매칭 태그: Adventure, Racing
# --- 총 다운로드 수: 4500개 ---
# [Tactical Warfare Simulator] - 22개 스크린샷, 매칭 태그: Adventure, Simulation
# [Blood City] - 12개 스크린샷, 매칭 태그: Adventure
# [Magnesium_173] - 6개 스크린샷, 매칭 태그: Puzzle
# [Quest for Cathay Kingdom Mah Jong] - 11개 스크린샷, 매칭 태그: Puzzle
# [Hidden Desert War Top-Down 3D] - 5개 스크린샷, 매칭 태그: Strategy
# [The Agency of Anomalies: Mystic Hospital Collector's Edition] - 5개 스크린샷, 매칭 태그: Adventure
# [Digital Dungeon Tiles] - 12개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# --- 총 다운로드 수: 4600개 ---
# [Star Speeder] - 16개 스크린샷, 매칭 태그: Racing
# [Geneforge 5: Overthrow] - 6개 스크린샷, 매칭 태그: RPG, Strategy
# [Mary Skelter: Nightmares] - 12개 스크린샷, 매칭 태그: RPG, Strategy
# [Unsung Heroes: The Golden Mask] - 7개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [1000 Amps] - 4개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 4700개 ---
# [Gunball] - 13개 스크린샷, 매칭 태그: Sports
# [Trackmaster] - 15개 스크린샷, 매칭 태그: Racing
# [Brick Breaker] - 10개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Daldos] - 7개 스크린샷, 매칭 태그: Simulation, Strategy
# [MachRace] - 10개 스크린샷, 매칭 태그: Racing
# [The Sight in a mirror] - 7개 스크린샷, 매칭 태그: Adventure, Strategy
# [Alien Planet] - 6개 스크린샷, 매칭 태그: Adventure
# [Tokyo Rogue] - 8개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 4800개 ---
# [Pinball HD Collection] - 11개 스크린샷, 매칭 태그: Simulation
# [Mothlight] - 9개 스크린샷, 매칭 태그: RPG
# [Darwin's bots: Episode 1] - 7개 스크린샷, 매칭 태그: Adventure
# [Damascus] - 12개 스크린샷, 매칭 태그: RPG
# [Urban Trial Tricky™ Deluxe Edition] - 5개 스크린샷, 매칭 태그: Sports, Racing
# [Amoreon NightClub] - 6개 스크린샷, 매칭 태그: Simulation
# [Crimson Ranch] - 11개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Strazeal] - 4개 스크린샷, 매칭 태그: Strategy
# [Bitten! Someone has to be a villain] - 5개 스크린샷, 매칭 태그: Survival, Adventure, Strategy
# --- 총 다운로드 수: 4900개 ---
# [The Curse of Nordic Cove] - 8개 스크린샷, 매칭 태그: Adventure
# [Ambushed] - 14개 스크린샷, 매칭 태그: Shooter
# [Q.U.B.E: Director's Cut] - 13개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [Ossuary] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Zoo Empire] - 10개 스크린샷, 매칭 태그: Simulation, Strategy
# [Doge to the Moon] - 5개 스크린샷, 매칭 태그: Adventure
# [Ape Hit] - 22개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 5000개 ---
# [Investigator] - 12개 스크린샷, 매칭 태그: Adventure, Simulation
# [Sunshine & Overcast] - 5개 스크린샷, 매칭 태그: RPG
# [Fish Tycoon] - 6개 스크린샷, 매칭 태그: Simulation
# [Gra&Vity] - 8개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Roads of Rome 3] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Expeditions: Conquistador] - 7개 스크린샷, 매칭 태그: Survival, Adventure, RPG, Strategy
# --- 총 다운로드 수: 5100개 ---
# [Cinders Of Hades] - 17개 스크린샷, 매칭 태그: Shooter
# [Goddess Of War Essa] - 7개 스크린샷, 매칭 태그: Adventure, Shooter
# [Pocket Plants] - 5개 스크린샷, 매칭 태그: Simulation
# [Doler] - 5개 스크린샷, 매칭 태그: Adventure
# [White Lavender] - 8개 스크린샷, 매칭 태그: Adventure, RPG
# [Poly Puzzle: Cats] - 5개 스크린샷, 매칭 태그: Puzzle
# [Draoi] - 5개 스크린샷, 매칭 태그: RPG
# [Thunder Kid] - 10개 스크린샷, 매칭 태그: Shooter
# [Understand] - 6개 스크린샷, 매칭 태그: Puzzle
# [Grimoire Chronicles] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# --- 총 다운로드 수: 5200개 ---
# [Meditation VR] - 7개 스크린샷, 매칭 태그: Simulation
# [Masquerade: The Baubles of Doom] - 10개 스크린샷, 매칭 태그: Adventure
# [The Case of Maneki] - 8개 스크린샷, 매칭 태그: Adventure
# [Nevermind] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Dungless 2] - 5개 스크린샷, 매칭 태그: Sandbox, Adventure, Survival
# [Tango: The Adventure Game] - 11개 스크린샷, 매칭 태그: Adventure
# [Plenty: Skyhearth] - 10개 스크린샷, 매칭 태그: RPG
# [Carnivores: Dinosaur Hunter Reborn] - 7개 스크린샷, 매칭 태그: Survival, Adventure, Simulation, Shooter
# --- 총 다운로드 수: 5300개 ---
# [Calm Down, Stalin] - 8개 스크린샷, 매칭 태그: Simulation
# [Kandidatos] - 7개 스크린샷, 매칭 태그: Fighting
# [凯旋岛] - 5개 스크린샷, 매칭 태그: Adventure, Shooter
# [Empathy: Path of Whispers] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Super Toxicboy] - 16개 스크린샷, 매칭 태그: Adventure, Racing
# [Haunted House - The Murder] - 5개 스크린샷, 매칭 태그: Adventure
# [Prisoner] - 5개 스크린샷, 매칭 태그: Survival, Adventure
# --- 총 다운로드 수: 5400개 ---
# [Dynamic Dungeons Editor] - 5개 스크린샷, 매칭 태그: RPG
# [Horror In Valkeala] - 9개 스크린샷, 매칭 태그: Puzzle, Simulation
# [SHINRAI - Broken Beyond Despair] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# [From Dusk To Dawn] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [Kittens and Yarn] - 5개 스크린샷, 매칭 태그: Puzzle
# [Frisbee For Fun] - 6개 스크린샷, 매칭 태그: Sports, Adventure, Puzzle
# [BC Kings] - 12개 스크린샷, 매칭 태그: Strategy
# [EARTH DEFENSE FORCE 4.1 The Shadow of New Despair] - 15개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 5500개 ---
# [Toy Tanks] - 10개 스크린샷, 매칭 태그: Adventure
# [Hotel Transylvania 3: Monsters Overboard] - 8개 스크린샷, 매칭 태그: Adventure, RPG
# [Be Vigilant!] - 16개 스크린샷, 매칭 태그: Adventure, RPG
# [SICK] - 9개 스크린샷, 매칭 태그: Adventure, Shooter
# [HIT] - 12개 스크린샷, 매칭 태그: Survival, Shooter
# --- 총 다운로드 수: 5600개 ---
# [Fragments] - 9개 스크린샷, 매칭 태그: Adventure
# [RoadPunk] - 5개 스크린샷, 매칭 태그: Sports, Adventure, Simulation, Racing
# [The Herbalist] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [The Story Goes On] - 18개 스크린샷, 매칭 태그: Adventure
# [Pantsu Hunter: Back to the 90s] - 8개 스크린샷, 매칭 태그: Adventure
# [Rogue Stormers] - 13개 스크린샷, 매칭 태그: Shooter
# [Buyhads] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 5700개 ---
# [Minit Fun Racer] - 6개 스크린샷, 매칭 태그: Adventure, Racing
# [Yissa Deep Realms] - 16개 스크린샷, 매칭 태그: Adventure, Shooter
# [A Normal Lost Phone] - 8개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Big Rumble Boxing: Creed Champions] - 10개 스크린샷, 매칭 태그: Sports
# [Blame Him] - 17개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle, Strategy
# --- 총 다운로드 수: 5800개 ---
# [Russian Fishing 4] - 33개 스크린샷, 매칭 태그: Sports, Adventure, Simulation, RPG
# --- 총 다운로드 수: 5900개 ---
# [Tiny Hunter] - 9개 스크린샷, 매칭 태그: Adventure
# [Super Glitter Rush] - 9개 스크린샷, 매칭 태그: Shooter
# [Texas Holdem Poker: Solo King] - 29개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# --- 총 다운로드 수: 6000개 ---
# [Ninja Kunoichi] - 5개 스크린샷, 매칭 태그: Survival, Adventure, Simulation, Shooter
# --- 총 다운로드 수: 6100개 ---
# [One More Night: BiO Clinic] - 5개 스크린샷, 매칭 태그: Strategy
# [Peekaboo] - 17개 스크린샷, 매칭 태그: Survival
# [Echo Tokyo: An Intro] - 12개 스크린샷, 매칭 태그: Adventure
# [Gothic 3: Forsaken Gods Enhanced Edition] - 7개 스크린샷, 매칭 태그: Adventure, RPG
# [Resurgence: Earth United] - 19개 스크린샷, 매칭 태그: RPG
# [Space Pilgrim Episode III: Delta Pavonis] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Alchera] - 5개 스크린샷, 매칭 태그: Survival, Adventure
# [Farm Builder] - 7개 스크린샷, 매칭 태그: Strategy
# [Snakest] - 5개 스크린샷, 매칭 태그: Adventure, Simulation
# --- 총 다운로드 수: 6200개 ---
# [Immortal Darkness: Curse of The Pale King] - 12개 스크린샷, 매칭 태그: Adventure, Puzzle, RPG, Strategy
# [Geometric Feel the Beats] - 17개 스크린샷, 매칭 태그: Shooter, Music
# [Need for Spirit: Drink & Drive Simulator/醉驾模拟器] - 11개 스크린샷, 매칭 태그: Sports, Adventure, Simulation, Racing
# --- 총 다운로드 수: 6300개 ---
# [Escape 2042 - The Truth Defenders] - 6개 스크린샷, 매칭 태그: Adventure
# [A Room Beyond] - 16개 스크린샷, 매칭 태그: Adventure
# [Escape Ninja] - 15개 스크린샷, 매칭 태그: Simulation
# [War Ghost] - 66개 스크린샷, 매칭 태그: Simulation, Strategy
# --- 총 다운로드 수: 6400개 ---
# --- 총 다운로드 수: 6500개 ---
# [Love in Belarus] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle, RPG, Strategy
# [iB Cricket] - 18개 스크린샷, 매칭 태그: Sports, Simulation, Strategy
# [Elemental Defenders TD] - 7개 스크린샷, 매칭 태그: Survival, Simulation, Strategy
# --- 총 다운로드 수: 6600개 ---
# [F29 Retaliator] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [WarGround] - 8개 스크린샷, 매칭 태그: Strategy
# [Eternal Starlight VR] - 11개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [THORN DEMON HUNTER] - 5개 스크린샷, 매칭 태그: RPG
# [Shuffle World] - 15개 스크린샷, 매칭 태그: Puzzle, Music
# [Helheim Hassle] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 6700개 ---
# [The Deer] - 8개 스크린샷, 매칭 태그: Adventure
# [Ultimate Ski Jumping 2020] - 6개 스크린샷, 매칭 태그: Sports, Simulation
# [Phoenix Point] - 12개 스크린샷, 매칭 태그: RPG, Strategy
# [浮生箓 Floating Life] - 6개 스크린샷, 매칭 태그: Simulation
# [Introvert Quest] - 6개 스크린샷, 매칭 태그: Adventure, RPG
# [Lumini] - 6개 스크린샷, 매칭 태그: Adventure, Simulation
# [Mafia: Definitive Edition] - 9개 스크린샷, 매칭 태그: Adventure, Racing, Shooter
# --- 총 다운로드 수: 6800개 ---
# [EDGE OF DAWN] - 14개 스크린샷, 매칭 태그: Survival, Adventure
# [Pawn of the Dead] - 7개 스크린샷, 매칭 태그: Survival, Puzzle, Strategy
# [No Time To Explain Remastered] - 5개 스크린샷, 매칭 태그: Adventure
# [Human Sacrifice] - 7개 스크린샷, 매칭 태그: Adventure
# [Pierhead Arcade 2] - 5개 스크린샷, 매칭 태그: Sandbox, Simulation
# [Supreme: Pizza Empire] - 9개 스크린샷, 매칭 태그: Simulation, Strategy
# [Idol Manager] - 14개 스크린샷, 매칭 태그: Simulation, Strategy
# --- 총 다운로드 수: 6900개 ---
# [Sneaky Kitten] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [HoloLAB Champions] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# [Freeways] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation
# [CounterAttack] - 13개 스크린샷, 매칭 태그: Adventure, Shooter
# [ANCIENT SOULS : The Governor] - 9개 스크린샷, 매칭 태그: RPG, Strategy
# --- 총 다운로드 수: 7000개 ---
# [A Familiar Fairytale Dyslexic Text Based Adventure] - 8개 스크린샷, 매칭 태그: Adventure, Simulation
# [Semi-Sweet Tofu] - 5개 스크린샷, 매칭 태그: Adventure
# [Unlit] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Syrian Warfare] - 9개 스크린샷, 매칭 태그: Simulation, Strategy
# [Relik] - 9개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Lucid Cycle] - 13개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 7100개 ---
# [Jigsaw Puzzles: Master Artists of Old] - 8개 스크린샷, 매칭 태그: Puzzle
# [Valthirian Arc: Hero School Story 2] - 10개 스크린샷, 매칭 태그: Simulation, Fighting, RPG, Strategy
# [Mech Armada] - 9개 스크린샷, 매칭 태그: RPG, Strategy
# [Fabulous - Angela's True Colors] - 9개 스크린샷, 매칭 태그: Adventure, Strategy
# [Fine China] - 6개 스크린샷, 매칭 태그: Simulation
# [BadLands RoadTrip] - 10개 스크린샷, 매칭 태그: Adventure, RPG, Shooter
# --- 총 다운로드 수: 7200개 ---
# [Virus Madness - Dungeons of your Body] - 6개 스크린샷, 매칭 태그: Shooter, Simulation, RPG, Strategy
# [Mana Gloom] - 13개 스크린샷, 매칭 태그: Adventure, RPG
# [Nature Treks VR] - 10개 스크린샷, 매칭 태그: Simulation
# [Shadowgate] - 16개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 7300개 ---
# [Shadow of Valhalla] - 5개 스크린샷, 매칭 태그: Survival, Adventure, Simulation, RPG
# [Bunker Constructor] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [Bartlow's Dread Machine] - 20개 스크린샷, 매칭 태그: Shooter
# [Onimod Land] - 5개 스크린샷, 매칭 태그: Strategy
# [Blue Flame] - 13개 스크린샷, 매칭 태그: Adventure
# [Mini Motorways] - 8개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# --- 총 다운로드 수: 7400개 ---
# [Signal Decay] - 9개 스크린샷, 매칭 태그: Adventure, Strategy
# [3d Bridges] - 20개 스크린샷, 매칭 태그: Sandbox, Simulation
# [Cosmonator] - 9개 스크린샷, 매칭 태그: Shooter, RPG
# [GUILT: The Deathless] - 11개 스크린샷, 매칭 태그: Survival, RPG
# --- 총 다운로드 수: 7500개 ---
# [Illusion of L'Phalcia] - 8개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Illwinter's Floorplan Generator] - 19개 스크린샷, 매칭 태그: RPG
# [Lakeview Valley] - 6개 스크린샷, 매칭 태그: Sandbox, RPG
# [Ochitsubaki] - 5개 스크린샷, 매칭 태그: RPG
# [RAILROADS Online!] - 8개 스크린샷, 매칭 태그: Sandbox
# [Ghost Dimension] - 7개 스크린샷, 매칭 태그: Adventure, Racing
# [Farmington County: The Ultimate Farming Tycoon Simulator] - 13개 스크린샷, 매칭 태그: Sandbox, Adventure, Simulation, Strategy
# --- 총 다운로드 수: 7600개 ---
# [Caretaker Retribution] - 45개 스크린샷, 매칭 태그: Simulation
# [NIGHTSTAR: Rogue Wings] - 9개 스크린샷, 매칭 태그: Simulation
# [Der Geisterjäger / The Ghost Hunter] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 7700개 ---
# [Table Gun] - 8개 스크린샷, 매칭 태그: Adventure
# [CITY - 909] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Voxel Turf] - 13개 스크린샷, 매칭 태그: Sandbox, Simulation, Strategy
# [Switchblade] - 5개 스크린샷, 매칭 태그: Adventure
# [RGB Simulator] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation
# [Catch the Head] - 7개 스크린샷, 매칭 태그: Adventure
# [Boxplosion] - 10개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 7800개 ---
# [PRiO] - 8개 스크린샷, 매칭 태그: Adventure
# [Pocket Academy] - 6개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Xploquest 2] - 10개 스크린샷, 매칭 태그: Adventure, RPG
# [Steampunk Tower 2] - 8개 스크린샷, 매칭 태그: Strategy
# [New Star Manager] - 7개 스크린샷, 매칭 태그: Sports, Simulation, RPG
# [Cave under Richmordnom] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [The Hole] - 13개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# --- 총 다운로드 수: 7900개 ---
# [Intergalactic Bubbles] - 8개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Ymir] - 20개 스크린샷, 매칭 태그: Simulation, Strategy
# [Selfless Heroes] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# [Life Combinations] - 7개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 8000개 ---
# [The famous diver] - 8개 스크린샷, 매칭 태그: Simulation
# [From Orbit] - 7개 스크린샷, 매칭 태그: Strategy
# [Woodlands] - 10개 스크린샷, 매칭 태그: Survival, Adventure
# [Hidden Farm Top-Down 3D] - 5개 스크린샷, 매칭 태그: Adventure, Simulation
# ["Drop Blox"] - 6개 스크린샷, 매칭 태그: Puzzle, Simulation
# [Solitaire 3D] - 12개 스크린샷, 매칭 태그: Strategy
# [Arizona Rose and the Pharaohs' Riddles] - 12개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Inmates] - 8개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 8100개 ---
# [Win by Definition] - 5개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Zeltrus] - 12개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Disney Universe] - 5개 스크린샷, 매칭 태그: Adventure
# [Legion Tale] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Terramancer] - 7개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Void Explorer] - 6개 스크린샷, 매칭 태그: Adventure
# [Sillage] - 21개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 8200개 ---
# [A Blind Legend] - 5개 스크린샷, 매칭 태그: Adventure
# [Sky Sanctuary] - 6개 스크린샷, 매칭 태그: Sports
# [Welcome To Lakewood] - 5개 스크린샷, 매칭 태그: Adventure
# [The Stalin Subway: Red Veil] - 9개 스크린샷, 매칭 태그: Shooter
# [Suits: A Business RPG] - 7개 스크린샷, 매칭 태그: Adventure, RPG
# [Sable's Grimoire: Man And Elf] - 7개 스크린샷, 매칭 태그: Simulation
# [Catie in MeowmeowLand] - 12개 스크린샷, 매칭 태그: Adventure, Puzzle
# [180 SECONDS] - 11개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# --- 총 다운로드 수: 8300개 ---
# [R-Naught] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# [MineSweeper VR] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation
# [重装无限·Metal Infinite] - 5개 스크린샷, 매칭 태그: Survival, Adventure, RPG
# [Room to Grow] - 6개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Rebel Reenactment: Battle of the Wilderness] - 12개 스크린샷, 매칭 태그: Shooter, Simulation
# --- 총 다운로드 수: 8400개 ---
# [Endless Furry Asteroids] - 7개 스크린샷, 매칭 태그: Shooter, Strategy
# [Tank Battle: North Africa] - 6개 스크린샷, 매칭 태그: Strategy
# [Chaos Starter] - 7개 스크린샷, 매칭 태그: Adventure, Simulation, Fighting
# [Seconds in Space] - 16개 스크린샷, 매칭 태그: Strategy
# [I, Hope] - 12개 스크린샷, 매칭 태그: Adventure
# [Leafling] - 16개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 8500개 ---
# [Resonance Wars] - 7개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [X-Plane 10 Global - 64 Bit] - 20개 스크린샷, 매칭 태그: Adventure, Simulation
# [PrimeOrbial] - 5개 스크린샷, 매칭 태그: Adventure, Simulation
# [The Elementalist] - 39개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 8600개 ---
# [Bongo Arena] - 5개 스크린샷, 매칭 태그: Strategy
# [Nightmare Survival] - 5개 스크린샷, 매칭 태그: Survival, Shooter
# [TYRONE vs COPS] - 5개 스크린샷, 매칭 태그: Shooter
# [Gem Tower Defense 2] - 10개 스크린샷, 매칭 태그: Strategy
# [It Stares Back] - 13개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# --- 총 다운로드 수: 8700개 ---
# [JCB Pioneer: Mars] - 15개 스크린샷, 매칭 태그: Survival, Adventure, Simulation
# [Atlantis 2: Beyond Atlantis] - 6개 스크린샷, 매칭 태그: Adventure
# [Electronic Super Joy 2] - 8개 스크린샷, 매칭 태그: Music
# [Aether Drift] - 11개 스크린샷, 매칭 태그: Fighting
# [Color By] - 30개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 8800개 ---
# [Expect The Unexpected] - 6개 스크린샷, 매칭 태그: Survival, RPG, Strategy
# [Vacation Adventures: Park Ranger 4] - 6개 스크린샷, 매칭 태그: Puzzle
# [The Rusty Sword: Vanguard Island] - 6개 스크린샷, 매칭 태그: Adventure
# [MonsterxMan: Inheritence To Lust] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [September 28 Pizza] - 10개 스크린샷, 매칭 태그: Shooter
# [Game Corp DX] - 7개 스크린샷, 매칭 태그: Sandbox, Simulation, Strategy
# [RENEGADE: ARENA SHOOTER] - 16개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 8900개 ---
# [Rakuen] - 14개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# [Kinetic Void] - 24개 스크린샷, 매칭 태그: Sandbox, Adventure, Simulation
# --- 총 다운로드 수: 9000개 ---
# [sfäre] - 12개 스크린샷, 매칭 태그: Sandbox
# [Hidden Paws] - 9개 스크린샷, 매칭 태그: Puzzle
# [Gladio and Glory] - 10개 스크린샷, 매칭 태그: Sandbox, Simulation, Fighting, Strategy
# [Way to Go!] - 17개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 9100개 ---
# [Sunset Planet] - 8개 스크린샷, 매칭 태그: Adventure, Strategy
# [Vaccine19] - 7개 스크린샷, 매칭 태그: Shooter
# [WestLand Adventure] - 5개 스크린샷, 매칭 태그: Adventure
# [Qipa World-Hello Big Adventure] - 18개 스크린샷, 매칭 태그: Adventure
# [My Little Blacksmith Shop] - 12개 스크린샷, 매칭 태그: Simulation
# [火柴人联盟2] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [CS Horizon] - 5개 스크린샷, 매칭 태그: Shooter, Simulation
# [MoveUp] - 5개 스크린샷, 매칭 태그: Adventure
# [BLUE WISH DESIRE] - 5개 스크린샷, 매칭 태그: Sports, Adventure, Simulation, Shooter
# --- 총 다운로드 수: 9200개 ---
# [Rinlo] - 8개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Awe] - 8개 스크린샷, 매칭 태그: Puzzle, Simulation
# [Emiko's Pledge] - 8개 스크린샷, 매칭 태그: Adventure, Shooter
# [Idle Champions of the Forgotten Realms] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [I am an Air Traffic Controller 4] - 21개 스크린샷, 매칭 태그: Simulation
# [Plan Z] - 15개 스크린샷, 매칭 태그: Survival, Shooter
# --- 총 다운로드 수: 9300개 ---
# [The Kings' Crusade] - 16개 스크린샷, 매칭 태그: Strategy
# [Devil's Toy] - 5개 스크린샷, 매칭 태그: Adventure
# [Dungeons and Dinners] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Solitaire Game Halloween 2] - 5개 스크린샷, 매칭 태그: Adventure
# [Tonikk Tycoon] - 9개 스크린샷, 매칭 태그: Strategy, Simulation, Puzzle, Sandbox, Shooter
# --- 총 다운로드 수: 9400개 ---
# [Heileen 3: New Horizons] - 18개 스크린샷, 매칭 태그: Adventure, Simulation
# [Vistascapes VR] - 24개 스크린샷, 매칭 태그: Adventure, Simulation
# [Code 9] - 6개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 9500개 ---
# [CrisisActionVR] - 6개 스크린샷, 매칭 태그: Adventure
# [Area 86] - 5개 스크린샷, 매칭 태그: Sandbox, Puzzle, Simulation
# [Zahalia] - 6개 스크린샷, 매칭 태그: Adventure
# [Life of Fly 2] - 8개 스크린샷, 매칭 태그: Simulation
# [Fruitlockers Reborn! 2] - 6개 스크린샷, 매칭 태그: Strategy
# [יום פתוח (Open Day)] - 20개 스크린샷, 매칭 태그: Adventure, RPG
# [Beyond Extinct] - 13개 스크린샷, 매칭 태그: Adventure
# [I'm a love interest in my childhood friend's reverse harem!!!] - 5개 스크린샷, 매칭 태그: Simulation
# [MagiCats Builder (Crazy Dreamz)] - 14개 스크린샷, 매칭 태그: Sandbox, Adventure, Puzzle
# --- 총 다운로드 수: 9600개 ---
# [Rugosi] - 5개 스크린샷, 매칭 태그: Adventure
# [PANIC STATION] - 5개 스크린샷, 매칭 태그: Survival, Adventure, Simulation
# [Kombine] - 5개 스크린샷, 매칭 태그: Puzzle, Strategy
# [The Advisor - Episode 1: Royal Pain] - 5개 스크린샷, 매칭 태그: Survival, RPG
# [Faye: A Tale of Shadow] - 14개 스크린샷, 매칭 태그: RPG, Strategy
# --- 총 다운로드 수: 9700개 ---
# [Super Plexis] - 7개 스크린샷, 매칭 태그: Puzzle
# [IMPALE YOUR FRIENDS!] - 6개 스크린샷, 매칭 태그: Fighting
# [心の闇の先に Trial VersionⅡ] - 5개 스크린샷, 매칭 태그: Adventure
# [Handball Action Total] - 11개 스크린샷, 매칭 태그: Sports, Simulation
# [Animals Memory: Insect] - 6개 스크린샷, 매칭 태그: Puzzle
# [WhiteLily 1：丽丽公主] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle, RPG, Strategy
# [Party Tycoon] - 15개 스크린샷, 매칭 태그: Simulation, Strategy
# --- 총 다운로드 수: 9800개 ---
# [Rollers] - 9개 스크린샷, 매칭 태그: Simulation, Strategy
# [GACHIMUCHI The Card Game] - 5개 스크린샷, 매칭 태그: Sports, Adventure, Strategy, Simulation, RPG
# [Station Commander] - 5개 스크린샷, 매칭 태그: Strategy
# [Clicker bAdventure] - 5개 스크린샷, 매칭 태그: Adventure
# [The New California] - 5개 스크린샷, 매칭 태그: Adventure
# [Edna & Harvey: The Breakout - Anniversary Edition] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Death off the Cuff] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 9900개 ---
# [Acaratus] - 16개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Scrap Galaxy] - 16개 스크린샷, 매칭 태그: Shooter, Simulation
# [Desktop Dungeons] - 17개 스크린샷, 매칭 태그: Puzzle, RPG
# --- 총 다운로드 수: 10000개 ---
# [Timerunner] - 14개 스크린샷, 매칭 태그: Adventure, Strategy, Simulation, Sandbox, Shooter
# [Edvog Explorer Game] - 5개 스크린샷, 매칭 태그: Adventure, Simulation
# --- 총 다운로드 수: 10100개 ---
# [Edwardo] - 8개 스크린샷, 매칭 태그: Strategy
# [Timothy ティモシー -神秘の森-] - 8개 스크린샷, 매칭 태그: Adventure
# [Jake's Love Story] - 7개 스크린샷, 매칭 태그: Adventure
# [CrunchTime] - 6개 스크린샷, 매칭 태그: Adventure
# [Primate Signal] - 5개 스크린샷, 매칭 태그: Adventure
# [Grandmaster Chess] - 8개 스크린샷, 매칭 태그: Strategy
# [Obscure Doubt] - 5개 스크린샷, 매칭 태그: RPG
# [Tenshu General] - 7개 스크린샷, 매칭 태그: Strategy
# [Bricks Frenzy] - 6개 스크린샷, 매칭 태그: Sports, Puzzle
# [Pixel Arcade] - 6개 스크린샷, 매칭 태그: Adventure, Simulation
# [Astro Tripper] - 8개 스크린샷, 매칭 태그: Shooter
# [Apex Legends™] - 5개 스크린샷, 매칭 태그: Survival, Shooter
# [Dualism] - 16개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 10200개 ---
# [Aura of Worlds] - 12개 스크린샷, 매칭 태그: Adventure
# [Ricochet Ranger] - 6개 스크린샷, 매칭 태그: Survival, Shooter, Strategy
# [The Marson Home] - 10개 스크린샷, 매칭 태그: Adventure
# [Mosaique Neko Waifus 2] - 13개 스크린샷, 매칭 태그: Puzzle, RPG
# [MelDEV Power Boat Racing] - 6개 스크린샷, 매칭 태그: Simulation, Racing
# [Magic Nations - Card Game] - 7개 스크린샷, 매칭 태그: Puzzle, Strategy
# --- 총 다운로드 수: 10300개 ---
# [Little Square Things] - 17개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Gardens Inc. 2: The Road to Fame] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [Bloxiq VR] - 9개 스크린샷, 매칭 태그: Puzzle, Strategy
# [VIDEO GAME] - 8개 스크린샷, 매칭 태그: Sports
# [INTRUDER - WAR AREAS] - 17개 스크린샷, 매칭 태그: Simulation
# [Darken VR] - 7개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 10400개 ---
# [Whiskers & Tail] - 9개 스크린샷, 매칭 태그: Puzzle
# [Boulders: Puzzle] - 6개 스크린샷, 매칭 태그: Puzzle
# [Chesnakisnak] - 8개 스크린샷, 매칭 태그: Adventure
# [Key] - 7개 스크린샷, 매칭 태그: Adventure, Strategy
# [Valley Run] - 5개 스크린샷, 매칭 태그: Racing
# [Space Duty] - 6개 스크린샷, 매칭 태그: Adventure, RPG
# [Catsapults] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [DCS World Steam Edition] - 7개 스크린샷, 매칭 태그: Sandbox, Shooter, Simulation, Strategy
# [SEARCH ALL - POTIONS] - 6개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 10500개 ---
# [Royal Defense] - 5개 스크린샷, 매칭 태그: Strategy
# [Whiskey & Zombies: The Great Southern Zombie Escape] - 12개 스크린샷, 매칭 태그: Survival, Adventure, Fighting, Strategy
# [Shadowrun: Hong Kong - Extended Edition] - 14개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [Tidalis] - 10개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 10600개 ---
# [battle Tank] - 5개 스크린샷, 매칭 태그: Simulation
# [White Haven Mysteries] - 10개 스크린샷, 매칭 태그: Adventure
# [VELONE] - 8개 스크린샷, 매칭 태그: Sandbox, Puzzle, Simulation
# [World of Subways 3 – London Underground Circle Line] - 20개 스크린샷, 매칭 태그: Adventure, Simulation
# [Planet of the Eyes] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [City Quest] - 19개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 10700개 ---
# [Skeleton Scramble Deluxe] - 8개 스크린샷, 매칭 태그: Strategy
# [Cultivation Tales] - 18개 스크린샷, 매칭 태그: Adventure, Strategy, Survival, RPG, Sandbox
# --- 총 다운로드 수: 10800개 ---
# [Space Pirate Trainer] - 5개 스크린샷, 매칭 태그: Shooter
# [MMA Executive] - 9개 스크린샷, 매칭 태그: Sports, Simulation, Strategy
# [Happy Quest] - 5개 스크린샷, 매칭 태그: Adventure, Strategy
# [Sakura Spirit] - 7개 스크린샷, 매칭 태그: Simulation
# [Data mining 2] - 5개 스크린샷, 매칭 태그: Puzzle
# [Guns of Succubus] - 6개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Shooter
# [Intake] - 5개 스크린샷, 매칭 태그: Shooter, Music
# --- 총 다운로드 수: 10900개 ---
# [KAMIKO] - 6개 스크린샷, 매칭 태그: Adventure
# [Apocalypse Mechanism] - 17개 스크린샷, 매칭 태그: Adventure
# [Bacon Rebellion] - 8개 스크린샷, 매칭 태그: Shooter
# [Gabe Newell Simulator] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, Shooter
# [Epic Manager - Create Your Own Adventuring Agency!] - 12개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Strategy
# [A Little Bird] - 6개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 11000개 ---
# [In Case of Emergency, Release Raptor] - 15개 스크린샷, 매칭 태그: Adventure
# [Adventure Apes and the Mayan Mystery] - 6개 스크린샷, 매칭 태그: Adventure
# [Sphere Game] - 6개 스크린샷, 매칭 태그: Adventure, Racing
# [Sword of Destiny] - 6개 스크린샷, 매칭 태그: Adventure
# [Marginalia] - 8개 스크린샷, 매칭 태그: Adventure
# [ZAR] - 10개 스크린샷, 매칭 태그: Survival, Shooter
# [Feather Of Praying 羽翼的祈愿] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [GOD EATER 2 Rage Burst] - 5개 스크린샷, 매칭 태그: RPG
# [Consumed Awakening] - 6개 스크린샷, 매칭 태그: Strategy
# [Better Off Tread] - 11개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 11100개 ---
# [Asian Riddles 4] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [270 | Two Seventy US Election] - 5개 스크린샷, 매칭 태그: Strategy
# [Ys VI: The Ark of Napishtim] - 21개 스크린샷, 매칭 태그: Adventure, RPG
# [Spare Teeth VR] - 8개 스크린샷, 매칭 태그: Sports
# [Beat Da Beat] - 5개 스크린샷, 매칭 태그: Music
# [American Truck Simulator] - 12개 스크린샷, 매칭 태그: Adventure, Simulation
# [The Endless Empty] - 13개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# --- 총 다운로드 수: 11200개 ---
# [Breakpoint] - 5개 스크린샷, 매칭 태그: Shooter
# [Bound Up & Squirming!] - 15개 스크린샷, 매칭 태그: Adventure, Simulation
# [Highway of death] - 5개 스크린샷, 매칭 태그: Simulation, Music, Racing
# [银魂：Silver Soul] - 16개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# --- 총 다운로드 수: 11300개 ---
# [Pizza Man] - 9개 스크린샷, 매칭 태그: Simulation, Racing
# [Popo's Tower] - 8개 스크린샷, 매칭 태그: Adventure
# [UAYEB: The Dry Land - Episode 1] - 20개 스크린샷, 매칭 태그: Survival, Adventure, Puzzle
# --- 총 다운로드 수: 11400개 ---
# [Girls & sweets] - 5개 스크린샷, 매칭 태그: Simulation, RPG
# [Card Battle Spirit Link] - 8개 스크린샷, 매칭 태그: Strategy
# [Cheese Runner] - 7개 스크린샷, 매칭 태그: Strategy
# [Krai Mira: Extended Cut] - 8개 스크린샷, 매칭 태그: Adventure, RPG
# [Terminal Singularity] - 10개 스크린샷, 매칭 태그: Strategy
# [Tank Sudoku] - 6개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Black Butterfly] - 21개 스크린샷, 매칭 태그: Survival, Puzzle, Shooter
# --- 총 다운로드 수: 11500개 ---
# [The Facility] - 6개 스크린샷, 매칭 태그: Adventure
# [I Can't Believe It's Not Gambling] - 9개 스크린샷, 매칭 태그: Simulation
# [Rogalia] - 14개 스크린샷, 매칭 태그: Sandbox, Adventure, RPG, Survival
# --- 총 다운로드 수: 11600개 ---
# [Mission Runway] - 12개 스크린샷, 매칭 태그: Simulation
# [Leisure Suit Larry 5 - Passionate Patti Does a Little Undercover Work] - 13개 스크린샷, 매칭 태그: Adventure
# [The Great Chicken Thief] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [Golazo! Soccer League] - 6개 스크린샷, 매칭 태그: Sports
# [Tartaron] - 5개 스크린샷, 매칭 태그: Shooter
# [Mare] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Black Skylands] - 16개 스크린샷, 매칭 태그: Adventure, Survival, Simulation, RPG, Sandbox
# --- 총 다운로드 수: 11700개 ---
# [Real Farm – Gold Edition] - 12개 스크린샷, 매칭 태그: Simulation, Strategy
# [牛头人迷宫/Tauren maze] - 6개 스크린샷, 매칭 태그: Survival, Adventure
# [Shootvaders: The Beginning] - 6개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 11800개 ---
# [Into the Pyramid] - 5개 스크린샷, 매칭 태그: Sandbox, Adventure
# [Lost Planet® 2] - 14개 스크린샷, 매칭 태그: Adventure, Shooter
# [Skip's Sanity] - 5개 스크린샷, 매칭 태그: Sports, Simulation, RPG, Strategy
# [Secret Laboratory] - 8개 스크린샷, 매칭 태그: Shooter
# [Tiny Wheels] - 9개 스크린샷, 매칭 태그: Simulation
# [ZEE.END] - 28개 스크린샷, 매칭 태그: Survival, Adventure, RPG, Shooter
# --- 총 다운로드 수: 11900개 ---
# [Aetheria Online] - 7개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 12000개 ---
# [Pull Ball] - 12개 스크린샷, 매칭 태그: Puzzle, Strategy
# [The Door in the Basement] - 16개 스크린샷, 매칭 태그: Survival, Adventure
# [War on the Sea] - 14개 스크린샷, 매칭 태그: Simulation, Strategy
# [天际起源 The Ark of Horizon] - 7개 스크린샷, 매칭 태그: Survival, Adventure, RPG, Shooter
# --- 총 다운로드 수: 12100개 ---
# [Austerlitz] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [Beaver Fun™ River Run - Steam Edition] - 9개 스크린샷, 매칭 태그: Sports, Racing
# [Liquid Pinball] - 7개 스크린샷, 매칭 태그: Puzzle
# [Zoo Tycoon: Ultimate Animal Collection] - 7개 스크린샷, 매칭 태그: Sandbox, Simulation
# [Age of Castles: Warlords] - 9개 스크린샷, 매칭 태그: Simulation, Strategy
# [Arobynn: The First Adventure] - 27개 스크린샷, 매칭 태그: Survival, Adventure, Shooter
# --- 총 다운로드 수: 12200개 ---
# [Wonder Boy: Asha in Monster World] - 11개 스크린샷, 매칭 태그: Adventure, RPG
# [Fighting Fiends] - 5개 스크린샷, 매칭 태그: Fighting
# [Beer, Babes and Dragons] - 5개 스크린샷, 매칭 태그: RPG
# [After I met that catgirl, my questlist got too long!] - 12개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 12300개 ---
# [The Revenge of Johnny Bonasera: Episode 1] - 7개 스크린샷, 매칭 태그: Adventure
# [Sanguo: War Under Heaven] - 5개 스크린샷, 매칭 태그: Strategy
# [细胞战争] - 7개 스크린샷, 매칭 태그: Simulation
# [B.A.D Battle Armor Division] - 8개 스크린샷, 매칭 태그: Shooter
# [Infinity Valley] - 5개 스크린샷, 매칭 태그: Racing
# [Dragon Fantasy: The Volumes of Westeria] - 5개 스크린샷, 매칭 태그: RPG
# [Ethan: Meteor Hunter] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Feign] - 8개 스크린샷, 매칭 태그: Survival, RPG, Strategy
# [Ashes] - 5개 스크린샷, 매칭 태그: Survival, Adventure
# --- 총 다운로드 수: 12400개 ---
# [Crimson Light] - 9개 스크린샷, 매칭 태그: RPG
# [Prototype Mansion - Used No Cover] - 6개 스크린샷, 매칭 태그: Adventure
# [Dark Romance: Sleepy Hollow Collector's Edition] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Connect The Dots] - 11개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Tunnels of Despair] - 8개 스크린샷, 매칭 태그: Survival, Adventure
# [The story of archer] - 7개 스크린샷, 매칭 태그: Survival, Adventure, RPG
# [LifeBase] - 6개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 12500개 ---
# [Mazes and Mages] - 5개 스크린샷, 매칭 태그: Strategy
# [ANIME REDEMPTION] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Shooter
# [Hotel Blind] - 5개 스크린샷, 매칭 태그: Simulation
# [Discouraged Workers] - 22개 스크린샷, 매칭 태그: Adventure
# [What The Fork] - 12개 스크린샷, 매칭 태그: Strategy
# [Puzzle Art: Primates] - 5개 스크린샷, 매칭 태그: Puzzle
# [Rocket of Whispers: Prologue] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [MUD Motocross World Championship] - 11개 스크린샷, 매칭 태그: Sports, Racing
# --- 총 다운로드 수: 12600개 ---
# [Long Live The Queen] - 12개 스크린샷, 매칭 태그: Simulation, RPG, Strategy
# [√Letter - Root Letter -] - 14개 스크린샷, 매칭 태그: Adventure
# [一花一世界 | The Lotus] - 5개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Cross of Auria] - 5개 스크린샷, 매칭 태그: RPG
# [STRAY KITTEN] - 5개 스크린샷, 매칭 태그: Sports, Adventure, Strategy, Survival, Simulation, RPG, Racing, Shooter
# --- 총 다운로드 수: 12700개 ---
# [Russian Gangsta In HELL] - 5개 스크린샷, 매칭 태그: Adventure
# [Mech Merc Company] - 8개 스크린샷, 매칭 태그: Shooter, Simulation
# [GangV | VR & PC Battle Royale] - 6개 스크린샷, 매칭 태그: Shooter, Racing
# [Briefcase Inc.] - 9개 스크린샷, 매칭 태그: Adventure
# [Alone In The Mars] - 5개 스크린샷, 매칭 태그: Shooter
# [Coin-Op Kingdom] - 7개 스크린샷, 매칭 태그: Sandbox, Simulation, Strategy
# [Nikopol: Secrets of the Immortals] - 14개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 12800개 ---
# [Chess Brain: Dark Troops] - 6개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Rift Wizard] - 10개 스크린샷, 매칭 태그: RPG, Strategy
# [Juliantli] - 5개 스크린샷, 매칭 태그: Music
# [Wake Up] - 5개 스크린샷, 매칭 태그: Adventure
# [Glizzy Gobbler] - 8개 스크린샷, 매칭 태그: Adventure
# [Shapeshooter] - 6개 스크린샷, 매칭 태그: Adventure, Music
# [Thea 2: The Shattering] - 17개 스크린샷, 매칭 태그: Survival, RPG, Strategy
# --- 총 다운로드 수: 12900개 ---
# [Maze Gold Run] - 5개 스크린샷, 매칭 태그: Adventure
# [Last Space Guardian] - 8개 스크린샷, 매칭 태그: Adventure
# [Fatal Evidence: Cursed Island Collector's Edition] - 10개 스크린샷, 매칭 태그: Adventure
# [Urban riots] - 8개 스크린샷, 매칭 태그: Adventure
# [Tales of the Neon Sea] - 7개 스크린샷, 매칭 태그: Adventure, Puzzle
# [MetaTron] - 9개 스크린샷, 매칭 태그: Survival
# [Jesus Christ RPG Trilogy] - 6개 스크린샷, 매칭 태그: RPG
# [King Arthur's Gold] - 10개 스크린샷, 매칭 태그: Sandbox, Adventure, Strategy
# --- 총 다운로드 수: 13000개 ---
# [GraFi Christmas] - 5개 스크린샷, 매칭 태그: Puzzle
# [Wife Quest] - 17개 스크린샷, 매칭 태그: Adventure, RPG
# [Indecision.] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Voidspire Tactics] - 7개 스크린샷, 매칭 태그: RPG, Strategy
# [Tail Trail] - 29개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 13100개 ---
# [Space Ace] - 12개 스크린샷, 매칭 태그: Adventure
# [HANDMADE CARPROGRAM] - 34개 스크린샷, 매칭 태그: Simulation
# [The Dream of Shadowlands Episode 2] - 5개 스크린샷, 매칭 태그: Survival, RPG
# [Lost to Time] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# [No King No Kingdom] - 14개 스크린샷, 매칭 태그: Sandbox, Simulation, RPG, Strategy
# --- 총 다운로드 수: 13200개 ---
# [SEARCH ALL - BITCOIN] - 5개 스크린샷, 매칭 태그: Puzzle
# [Star Renegades] - 9개 스크린샷, 매칭 태그: RPG, Strategy
# [BLASK] - 9개 스크린샷, 매칭 태그: Puzzle
# [Another Hardcore Game] - 10개 스크린샷, 매칭 태그: Adventure
# [Justice Chronicles] - 8개 스크린샷, 매칭 태그: RPG
# [Bus Mechanic Simulator] - 20개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 13300개 ---
# [Z Arena] - 18개 스크린샷, 매칭 태그: Survival, Adventure, Shooter
# [Nectar of the Gods] - 6개 스크린샷, 매칭 태그: Strategy
# [Sanity of Morris] - 10개 스크린샷, 매칭 태그: Adventure
# [Ayahuasca: Polyventure] - 7개 스크린샷, 매칭 태그: Adventure, Simulation, Strategy
# [Dragon Mission] - 7개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 13400개 ---
# [Billiards of the Round Table (BRT)] - 5개 스크린샷, 매칭 태그: Sports, Puzzle
# [舔狗模拟器] - 12개 스크린샷, 매칭 태그: RPG
# [Rogue Spirit] - 23개 스크린샷, 매칭 태그: Adventure
# [Elven Love] - 10개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle
# [Chop Chop Princess!] - 7개 스크린샷, 매칭 태그: Adventure, Racing
# [Emily: Displaced] - 10개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 13500개 ---
# [Fallen Earth Classic] - 11개 스크린샷, 매칭 태그: Adventure, Survival, RPG, Sandbox, Shooter
# [大乱斗 Chaos Battle] - 7개 스크린샷, 매칭 태그: Adventure, Strategy
# [Thieves' Gambit: The Curse of the Black Cat] - 5개 스크린샷, 매칭 태그: RPG
# [Tyrfing  Cycle |Vanilla|] - 10개 스크린샷, 매칭 태그: Adventure
# [LuckCatchers] - 13개 스크린샷, 매칭 태그: Sandbox, Simulation, RPG, Strategy
# --- 총 다운로드 수: 13600개 ---
# [魔法考核冒险] - 6개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# [Bepuzzled Jigsaw Puzzle: Sweets] - 6개 스크린샷, 매칭 태그: Puzzle
# [Trivia Vault: Health Trivia Deluxe] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# [All Of ZHEM] - 8개 스크린샷, 매칭 태그: Shooter
# [Necromunda: Hired Gun] - 5개 스크린샷, 매칭 태그: Adventure, Shooter
# [Scary Humans] - 19개 스크린샷, 매칭 태그: Survival
# --- 총 다운로드 수: 13700개 ---
# [Tennis Elbow 4] - 12개 스크린샷, 매칭 태그: Sports, Simulation
# [Fallout: New Vegas] - 12개 스크린샷, 매칭 태그: Adventure, Survival, RPG, Sandbox, Shooter
# --- 총 다운로드 수: 13800개 ---
# [StOoPiD Puzzle Game] - 20개 스크린샷, 매칭 태그: Puzzle
# [Disturbed] - 8개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle
# [Crowd Control] - 5개 스크린샷, 매칭 태그: Simulation, Strategy
# [The Lab] - 7개 스크린샷, 매칭 태그: Adventure, Strategy, Simulation, Puzzle, Sandbox, Shooter
# [SEARCH ALL - MUSHROOMS] - 6개 스크린샷, 매칭 태그: Puzzle
# --- 총 다운로드 수: 13900개 ---
# [Project Toon Tanks] - 20개 스크린샷, 매칭 태그: Shooter, Strategy
# [Rescue Team 3] - 6개 스크린샷, 매칭 태그: Simulation, Strategy
# [Flaming Friday Night] - 30개 스크린샷, 매칭 태그: RPG
# [Chocolate makes you happy: St.Patrick's Day] - 5개 스크린샷, 매칭 태그: Puzzle
# [Tactical Mind] - 9개 스크린샷, 매칭 태그: Strategy
# [Z.O.M.B.I.E.] - 6개 스크린샷, 매칭 태그: Survival, Adventure, Simulation, Shooter
# --- 총 다운로드 수: 14000개 ---
# [BARRIER X] - 6개 스크린샷, 매칭 태그: Adventure, Music, Strategy
# [Mystery Case Files®: 13th Skull™ Collector's Edition] - 8개 스크린샷, 매칭 태그: Adventure
# [Grim Tales: Crimson Hollow Collector's Edition] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Connectify] - 6개 스크린샷, 매칭 태그: Puzzle
# [Guns and Grapples] - 10개 스크린샷, 매칭 태그: Shooter
# [Project Lounge] - 7개 스크린샷, 매칭 태그: Sandbox
# [Kinetic Edge] - 17개 스크린샷, 매칭 태그: Adventure, Racing, Puzzle
# --- 총 다운로드 수: 14100개 ---
# [Alley Cat Bowling] - 8개 스크린샷, 매칭 태그: Sports, Simulation
# [Moon River] - 7개 스크린샷, 매칭 태그: Adventure
# [Crash Wheels] - 9개 스크린샷, 매칭 태그: Racing
# [Remnants] - 17개 스크린샷, 매칭 태그: Survival, Adventure, RPG
# --- 총 다운로드 수: 14200개 ---
# [Sphere Complex] - 9개 스크린샷, 매칭 태그: Simulation, Racing
# [Endless Knight] - 12개 스크린샷, 매칭 태그: Fighting
# [Alvora Tactics] - 6개 스크린샷, 매칭 태그: RPG, Strategy
# [Model Kit Simulator VR] - 5개 스크린샷, 매칭 태그: Simulation
# [REVOLT 1917] - 12개 스크린샷, 매칭 태그: Adventure
# [Better Late Than DEAD] - 6개 스크린샷, 매칭 태그: Sandbox, Adventure, Survival
# [Emily is Away <3] - 5개 스크린샷, 매칭 태그: Adventure, Simulation, RPG
# --- 총 다운로드 수: 14300개 ---
# [Ultimate Chess] - 8개 스크린샷, 매칭 태그: Sports, Strategy
# ...
# [C:\raft] - 9개 스크린샷, 매칭 태그: RPG
# [Mini Mini-Golf] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# --- 총 다운로드 수: 38900개 ---
# [Waste Walkers] - 17개 스크린샷, 매칭 태그: Sandbox, Adventure, RPG, Survival
# [Seabed Prelude] - 6개 스크린샷, 매칭 태그: Adventure, Simulation
# [Dashing Fire] - 7개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 39000개 ---
# [我就是要红] - 5개 스크린샷, 매칭 태그: Simulation, RPG
# [Layers of Fear VR] - 6개 스크린샷, 매칭 태그: Adventure
# [Filthy Frank Kart] - 8개 스크린샷, 매칭 태그: Racing
# [Primal Light] - 16개 스크린샷, 매칭 태그: Adventure
# [The Chosen Warriors] - 9개 스크린샷, 매칭 태그: Adventure
# [Kill Fun Yeah] - 10개 스크린샷, 매칭 태그: Shooter
# [冷月清辉照天涯(KUNG FU LEGEND)] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Ancient lands: the Tsar awakening] - 5개 스크린샷, 매칭 태그: Adventure, Strategy
# [Knights of Grumthorr] - 10개 스크린샷, 매칭 태그: Strategy
# [Ragnorium] - 10개 스크린샷, 매칭 태그: Adventure, Strategy, Survival, Simulation, RPG, Sandbox
# --- 총 다운로드 수: 39100개 ---
# [Salaryman Shi] - 5개 스크린샷, 매칭 태그: Adventure
# [RUSSIA BATTLEGROUNDS] - 10개 스크린샷, 매칭 태그: Adventure, RPG, Shooter
# [Mind Games] - 5개 스크린샷, 매칭 태그: Puzzle
# [Vectorium] - 13개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 39200개 ---
# [Kingdom Warrior] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Poly Memory: Furries] - 5개 스크린샷, 매칭 태그: Puzzle
# [愚者地牢-UP主的消失] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Seek Not a Lighthouse] - 5개 스크린샷, 매칭 태그: Adventure
# [Swiss Alps Jigsaw Puzzles] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [Smartphone Tycoon] - 18개 스크린샷, 매칭 태그: Simulation, Strategy
# [Homeland: Lay to Rest] - 5개 스크린샷, 매칭 태그: Adventure
# [Mirror Layers] - 6개 스크린샷, 매칭 태그: Survival, Adventure, Puzzle
# --- 총 다운로드 수: 39300개 ---
# [SPAGHET] - 5개 스크린샷, 매칭 태그: Strategy
# [Alpha Lyrae Discovery] - 10개 스크린샷, 매칭 태그: Adventure, Strategy, Simulation, RPG, Sandbox
# [Hive Jump] - 13개 스크린샷, 매칭 태그: Shooter
# [Yono and the Celestial Elephants] - 12개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 39400개 ---
# [PROTOThYPE _ a love story] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [BioShock™ Remastered] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Shooter
# [Rise and Fall] - 10개 스크린샷, 매칭 태그: Sports
# [Voyager] - 7개 스크린샷, 매칭 태그: Adventure
# [Landlord's Super] - 16개 스크린샷, 매칭 태그: Sandbox, Simulation, RPG
# [Full Metal Furies] - 15개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# --- 총 다운로드 수: 39500개 ---
# [Cricket Captain 2022] - 12개 스크린샷, 매칭 태그: Sports, Simulation, Strategy
# [Infinite Game Works Episode 0] - 6개 스크린샷, 매칭 태그: Simulation
# [A-Gents] - 20개 스크린샷, 매칭 태그: Shooter
# --- 총 다운로드 수: 39600개 ---
# [Salt and Sanctuary] - 10개 스크린샷, 매칭 태그: Adventure, RPG
# [Minions Battle] - 5개 스크린샷, 매칭 태그: Shooter, Simulation
# [Slime Kingdom] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [作死吧！UP主！] - 12개 스크린샷, 매칭 태그: Simulation, RPG
# [Trivia Vault: 1980's Trivia 2] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation, Strategy
# [Valiant Hearts: The Great War™ / Soldats Inconnus : Mémoires de la Grande Guerre™] - 9개 스크린샷, 매칭 태그: Adventure, Music, Puzzle
# --- 총 다운로드 수: 39700개 ---
# [Content Creator Simulator] - 6개 스크린샷, 매칭 태그: Simulation
# [Puzzle Dating] - 5개 스크린샷, 매칭 태그: Puzzle, Simulation
# [Night Trap - 25th Anniversary Edition] - 10개 스크린샷, 매칭 태그: Adventure
# [Heavy Bullets] - 11개 스크린샷, 매칭 태그: Adventure, Shooter
# [Diorama No.1 : Blocked In] - 5개 스크린샷, 매칭 태그: Simulation
# [Pilfered Liberty] - 6개 스크린샷, 매칭 태그: Shooter
# [Dunrog] - 6개 스크린샷, 매칭 태그: Adventure, RPG
# [Berzerk Flashback] - 10개 스크린샷, 매칭 태그: Sports, Adventure, RPG, Strategy
# --- 총 다운로드 수: 39800개 ---
# [Adventure Llama] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Raccoon The Miner] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle, Strategy
# [CyberClub-2077] - 20개 스크린샷, 매칭 태그: Sports, Simulation, Music
# --- 총 다운로드 수: 39900개 ---
# [Cragls] - 9개 스크린샷, 매칭 태그: Sports, Racing
# [Ruin Raiders] - 9개 스크린샷, 매칭 태그: RPG, Strategy
# [Tribal Pass] - 12개 스크린샷, 매칭 태그: Adventure
# [Adult Toy Store] - 12개 스크린샷, 매칭 태그: Simulation
# [Emu War!] - 14개 스크린샷, 매칭 태그: Sandbox, Simulation
# [Alpacapaca Double Dash] - 8개 스크린샷, 매칭 태그: Adventure, Puzzle, RPG, Strategy
# --- 총 다운로드 수: 40000개 ---
# [Blade and Sorcery] - 17개 스크린샷, 매칭 태그: Adventure, Simulation, Fighting, RPG, Sandbox
# --- 총 다운로드 수: 40100개 ---
# [Garden Rescue] - 5개 스크린샷, 매칭 태그: Strategy
# [Brutal Dinosaur] - 5개 스크린샷, 매칭 태그: Shooter
# [Gleaner Heights] - 19개 스크린샷, 매칭 태그: Adventure, Simulation, RPG
# [Brushwood Buddies] - 5개 스크린샷, 매칭 태그: Puzzle
# [1931: Scheherazade at the Library of Pergamum] - 7개 스크린샷, 매칭 태그: Simulation, RPG
# --- 총 다운로드 수: 40200개 ---
# [The Mensional] - 12개 스크린샷, 매칭 태그: Adventure, Puzzle
# [PIPI IS YOU] - 15개 스크린샷, 매칭 태그: Puzzle
# [Beware Planet Earth] - 13개 스크린샷, 매칭 태그: Strategy
# [Temple of Pizza] - 8개 스크린샷, 매칭 태그: Adventure, Simulation
# [孑游列国] - 6개 스크린샷, 매칭 태그: Adventure, Strategy
# [CYNOROID FORSAKEN] - 5개 스크린샷, 매칭 태그: Shooter
# [Real Warfare 1242] - 13개 스크린샷, 매칭 태그: Strategy
# --- 총 다운로드 수: 40300개 ---
# [Shikhondo(食魂徒) - Soul Eater] - 11개 스크린샷, 매칭 태그: Shooter
# [Destiny Warriors RPG] - 7개 스크린샷, 매칭 태그: Sandbox, Adventure, RPG
# [Firewerx] - 7개 스크린샷, 매칭 태그: Sandbox, Simulation
# [Cluck Yegger in Escape From The Planet of The Poultroid] - 9개 스크린샷, 매칭 태그: Strategy
# [CandyVenture] - 11개 스크린샷, 매칭 태그: Adventure
# [NULLORE: beginning] - 12개 스크린샷, 매칭 태그: Adventure
# [シオリノコトハ - Dark Reflections -] - 5개 스크린샷, 매칭 태그: Survival, Simulation
# [SAWKOBAN] - 8개 스크린샷, 매칭 태그: Puzzle
# [Art of Murder - Deadly Secrets] - 5개 스크린샷, 매칭 태그: Adventure
# --- 총 다운로드 수: 40400개 ---
# [Workers & Resources: Soviet Republic] - 14개 스크린샷, 매칭 태그: Simulation, Strategy
# [Shadow of the Tomb Raider: Definitive Edition] - 10개 스크린샷, 매칭 태그: Survival, Adventure, Shooter, Puzzle
# [Paradox Factor] - 7개 스크린샷, 매칭 태그: Adventure
# [Drums of War] - 8개 스크린샷, 매칭 태그: Adventure, Music
# [Fearful Symmetry & The Cursed Prince] - 10개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 40500개 ---
# [BOMB: Who let the dogfight?] - 12개 스크린샷, 매칭 태그: Adventure, Simulation
# [Haunted Legends: The Stone Guest Collector's Edition] - 10개 스크린샷, 매칭 태그: Adventure
# [Caramba!] - 9개 스크린샷, 매칭 태그: Adventure
# [Chefy-Chef] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Cloudlands : VR Minigolf] - 17개 스크린샷, 매칭 태그: Sports
# [CubeBall VR] - 11개 스크린샷, 매칭 태그: Simulation
# --- 총 다운로드 수: 40600개 ---
# [Koo & Yuu] - 5개 스크린샷, 매칭 태그: Puzzle
# [Samsara] - 9개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Ghost Master®] - 11개 스크린샷, 매칭 태그: Sandbox, Puzzle, Simulation, Strategy
# [Remnants Of Isolation] - 10개 스크린샷, 매칭 태그: RPG
# [HackyZack] - 9개 스크린샷, 매칭 태그: Sports, Puzzle
# [Killer Queen Black] - 10개 스크린샷, 매칭 태그: Sports, Fighting, Strategy
# --- 총 다운로드 수: 40700개 ---
# [Beer Pong VR] - 7개 스크린샷, 매칭 태그: Sports, Strategy
# [Space Ship DRIFT] - 5개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# [RPG MO] - 10개 스크린샷, 매칭 태그: Sandbox, Adventure, RPG
# [The Escapists] - 12개 스크린샷, 매칭 태그: Adventure, Strategy, Survival, Simulation, RPG, Puzzle, Sandbox
# --- 총 다운로드 수: 40800개 ---
# [Elteria Hunter] - 4개 스크린샷, 매칭 태그: Adventure, RPG, Strategy
# [MEANDERS] - 14개 스크린샷, 매칭 태그: Adventure, Puzzle
# --- 총 다운로드 수: 40900개 ---
# [Dark Parables: Portrait of the Stained Princess Collector's Edition] - 10개 스크린샷, 매칭 태그: Adventure
# [Insipid] - 5개 스크린샷, 매칭 태그: Puzzle
# [HellCrunch] - 11개 스크린샷, 매칭 태그: Shooter
# [Lawnmower Game: Space Fight] - 6개 스크린샷, 매칭 태그: Adventure, Shooter
# [Monolith] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [There Was the Moon] - 9개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Mystical Mayhem] - 5개 스크린샷, 매칭 태그: Adventure, Puzzle
# [STORM AREA 51: AYY LMAO EDITION] - 10개 스크린샷, 매칭 태그: Adventure, Simulation, RPG, Strategy
# --- 총 다운로드 수: 41000개 ---
# [Reverse Fantasy Legend 2] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Heartbound] - 5개 스크린샷, 매칭 태그: Adventure, RPG, Puzzle
# [MachiaVillain] - 11개 스크린샷, 매칭 태그: Sandbox, Simulation, Strategy
# [Temple of Xiala] - 5개 스크린샷, 매칭 태그: Puzzle
# [Call of Duty®: Black Ops] - 12개 스크린샷, 매칭 태그: Adventure, Shooter
# --- 총 다운로드 수: 41100개 ---
# [全民王者] - 8개 스크린샷, 매칭 태그: RPG
# [Zuma Deluxe] - 5개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Advancity] - 12개 스크린샷, 매칭 태그: Adventure, Simulation, Puzzle, Strategy
# [STAR OCEAN™ - THE LAST HOPE -™ 4K & Full HD Remaster] - 10개 스크린샷, 매칭 태그: Adventure, RPG
# [Deep Dark Dungeon] - 7개 스크린샷, 매칭 태그: RPG
# --- 총 다운로드 수: 41200개 ---
# [Lazy Galaxy: Rebel Story] - 12개 스크린샷, 매칭 태그: Shooter
# [Arcanion: Tale of Magi] - 11개 스크린샷, 매칭 태그: Adventure, Shooter
# [Terracosmic] - 6개 스크린샷, 매칭 태그: Survival, Adventure, Simulation, Strategy
# [Scoot Kaboom and the Tomb of Doom] - 9개 스크린샷, 매칭 태그: Adventure
# [Hailey] - 5개 스크린샷, 매칭 태그: Simulation
# [Startide] - 8개 스크린샷, 매칭 태그: Shooter
# [Hotline Miami] - 5개 스크린샷, 매칭 태그: Shooter, Music
# [Last Days] - 9개 스크린샷, 매칭 태그: Adventure, RPG
# --- 총 다운로드 수: 41300개 ---
# [Fatal Twelve] - 8개 스크린샷, 매칭 태그: Adventure
# [Nihilist Simulator] - 5개 스크린샷, 매칭 태그: Adventure, Simulation
# [Guided Meditation VR] - 12개 스크린샷, 매칭 태그: Simulation
# [Infectra] - 7개 스크린샷, 매칭 태그: Puzzle, Strategy
# [Fairytale Mosaics Cinderella 2] - 6개 스크린샷, 매칭 태그: Adventure, Puzzle
# [Shikokushi ~food and sightseeing and beauties~] - 9개 스크린샷, 매칭 태그: RPG, Strategy
# [天下往事 Journey of the world] - 5개 스크린샷, 매칭 태그: Adventure, RPG
# [Street Racing 2020] - 5개 스크린샷, 매칭 태그: Sports, Simulation, Racing
# --- 총 다운로드 수: 41400개 ---
# [Viking Heroes 2] - 9개 스크린샷, 매칭 태그: Adventure, Strategy
# [Orbiterrion] - 8개 스크린샷, 매칭 태그: Fighting
# [VeeR Pong] - 5개 스크린샷, 매칭 태그: Sports, Simulation
# [Night Road] - 10개 스크린샷, 매칭 태그: Adventure
# [Choco Pixel S] - 5개 스크린샷, 매칭 태그: Puzzle
# [AdvertCity] - 39개 스크린샷, 매칭 태그: Simulation, Strategy
# --- 총 다운로드 수: 41500개 ---
# [Disney Infinity 3.0: Gold Edition] - 5개 스크린샷, 매칭 태그: Sandbox, Adventure
# [Master of Magic Classic] - 5개 스크린샷, 매칭 태그: Strategy
# [Pizza Connection] - 9개 스크린샷, 매칭 태그: Simulation, Strategy
# [New Supper Banana!] - 6개 스크린샷, 매칭 태그: Adventure
# [WordTactics] - 13개 스크린샷, 매칭 태그: Puzzle, Strategy
# --- 총 다운로드 수: 41600개 ---
# [Slinger VR] - 8개 스크린샷, 매칭 태그: Sandbox, Adventure, Simulation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 196
#     193     print("-" * 50)
#     195 # 실행
# --> 196 process_game_data(FILE_PATH)
#
# Cell In[5], line 180, in process_game_data(file_path)
#     177 # --------------------------------------------------------------------
#     179 if screenshot_url:
# --> 180     if download_screenshot(screenshot_url, genre_dir, appid):
#     181         total_downloads += 1
#     182         current_count += 1
#
# Cell In[5], line 67, in download_screenshot(url, genre_folder, appid)
#      63     return True
#      65 try:
#      66     # 파일 다운로드 (스트리밍 사용)
# ---> 67     response = requests.get(url, stream=True, timeout=10)
#      68     response.raise_for_status() # HTTP 오류가 발생하면 예외 발생
#      70     with open(save_path, 'wb') as f:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\ProgramData\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import json
import requests
import os
from urllib.parse import urlparse
import time
import random
import concurrent.futures
import pandas as pd
from typing import Set, List, Dict, Tuple, Any

# --- 설정값 ---
FILE_PATH = 'games.json'  # ⚠️ JSON 파일 경로를 실제 파일 이름으로 변경하세요.
BASE_DOWNLOAD_DIR = r'F:\ML\MUFi'

TARGET_GENRE = "Action"
MAX_FILES_PER_GENRE = 12000

TARGET_TAGS = [
    "Adventure", "Action", "RPG", "Strategy", "Simulation", "Sports", "Racing", 
    "Puzzle", "Sandbox", "Shooter", "Survival", "Fighting", "Music"
]
MAX_WORKERS = 30  # 💡 동시 다운로드 스레드 수 (네트워크 상황에 맞게 조정)
# --------------------
# ----------------

def clean_filename(url):
    """URL에서 안전한 파일 이름을 추출하고 확장자를 포함합니다."""
    path = urlparse(url).path
    filename = os.path.basename(path)
    # 쿼리 파라미터나 기타 불필요한 문자를 제거하고 안전하게 만듭니다.
    if '?' in filename:
        filename = filename.split('?')[0]
    return filename

def get_genre_file_count(genre_dir):
    """장르 폴더 내의 실제 파일 개수를 계산합니다."""
    if not os.path.exists(genre_dir):
        return 0
    # .DS_Store 같은 숨김 파일을 제외하고 파일 개수를 셉니다.
    return len([name for name in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, name)) and not name.startswith('.')])

def manage_file_limit(genre_dir, max_limit):
    """폴더의 파일 수가 최대 한도를 초과할 경우 파일을 랜덤하게 삭제합니다."""
    current_count = get_genre_file_count(genre_dir)
    if current_count > max_limit:
        files_to_delete = current_count - max_limit
        all_files = [f for f in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, f)) and not f.startswith('.')]
        
        # 삭제할 파일을 랜덤하게 선택
        files_to_remove = random.sample(all_files, files_to_delete)
        
        print(f"[{os.path.basename(genre_dir)}] ❗️ 파일 초과: {current_count}개. {files_to_delete}개 삭제 중...")
        
        for file in files_to_remove:
            try:
                os.remove(os.path.join(genre_dir, file))
            except OSError as e:
                print(f"파일 삭제 오류: {e}")

def download_screenshot(url, genre_folder, appid):
    """스크린샷을 다운로드하고 장르 폴더에 저장합니다."""
    
    # 파일명 생성: AppID와 원래 파일명을 조합하여 중복 방지 및 추적 용이
    original_filename = clean_filename(url)
    filename = f"{appid}_{original_filename}"
    save_path = os.path.join(genre_folder, filename)

    if os.path.exists(save_path):
        # 파일이 이미 존재하면 건너뜁니다.
        # print(f"파일이 이미 존재하여 건너뜁니다: {filename}")
        return True

    try:
        # 파일 다운로드 (스트리밍 사용)
        response = requests.get(url, stream=True, timeout=10)
        response.raise_for_status() # HTTP 오류가 발생하면 예외 발생

        with open(save_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    
    except requests.exceptions.RequestException as e:
        # print(f"다운로드 실패 ({url}): {e}") # 디버그 출력 최소화
        return False, filename

def create_tag_vector(matching_tags: Set[str]) -> List[int]:
    """
    매칭되는 태그를 TARGET_TAGS 순서에 따른 원-핫 벡터로 변환합니다.
    """
    vector = [0] * len(TARGET_TAGS)
    for i, target_tag in enumerate(TARGET_TAGS):
        if target_tag in matching_tags:
            vector[i] = 1
    return vector

# (download_screenshot, clean_filename, get_genre_file_count, manage_file_limit 함수는 그대로 유지)


def process_game_data(file_path):
    """JSON 파일을 읽고 지정된 태그별로 스크린샷을 병렬로 다운로드합니다."""
    # ... (파일 로드 및 초기 설정 부분은 그대로 유지) ...
    """JSON 파일을 읽고 지정된 태그별로 스크린샷을 다운로드합니다."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"❌ 오류: 파일을 찾을 수 없습니다. 경로를 확인해 주세요: {file_path}")
        return
    except json.JSONDecodeError:
        print("❌ 오류: JSON 파일 형식이 올바르지 않습니다.")
        return

    if TARGET_GENRE not in TARGET_TAGS:
        print(f"❌ 오류: TARGET_GENRE '{TARGET_GENRE}'가 TARGET_TAGS에 없습니다. 설정을 확인하세요.")
        return
    
    # 기본 다운로드 디렉토리 생성 및 장르별 폴더 관리 (기존 코드 유지)
    # 단일 장르 폴더 설정
    genre_dir = os.path.join(BASE_DOWNLOAD_DIR, TARGET_GENRE)
    os.makedirs(genre_dir, exist_ok=True)
    manage_file_limit(genre_dir, TARGET_MAX_FILES)
    
    current_count = get_genre_file_count(genre_dir)

    game_list = data.values() if isinstance(data, dict) else data
    total_downloads = 0
    
    # for tag in TARGET_TAGS:
    #     genre_path = os.path.join(BASE_DOWNLOAD_DIR, tag)
    #     os.makedirs(genre_path, exist_ok=True)
    #     genre_dirs[tag] = genre_path
    #     manage_file_limit(genre_path, MAX_FILES_PER_GENRE)

    # game_list = data.values() if isinstance(data, dict) else data
    # total_downloads = 0

    # 💡 CSV 데이터 저장을 위한 딕셔너리 (파일명 중복 방지)
    # {filename: tag_vector} 형태로 저장
    csv_data_map: Dict[str, List[int]] = {}
    
    print("-" * 50)
    print(f"단일 장르 크롤링 시작: {TARGET_GENRE}")
    print(f"목표 파일 수: {TARGET_MAX_FILES}개 (현재 {current_count}개)")
    print("-" * 50)

    # 🚀 ThreadPoolExecutor를 사용하여 병렬 처리 시작
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        
        # 다운로드할 모든 작업(Future) 리스트
        future_to_info = []
        
        for appid, game in data.items():
            if not isinstance(game, dict):
                continue
                
            # 태그 처리 로직 (이전 수정 코드 그대로 유지)
            tags_data = game.get('tags')
            if isinstance(tags_data, dict):
                game_tags = set(tags_data.keys())
            elif isinstance(tags_data, list):
                game_tags = set(tags_data)
            else:
                continue
                
            matching_tags = game_tags.intersection(TARGET_TAGS)
            if not matching_tags:
                continue
                
            screenshots = game.get('screenshots', [])
            if not screenshots:
                continue
                
            # print(f"[{game.get('name', appid)}] - {len(screenshots)}개 스크린샷, 매칭 태그: {', '.join(matching_tags)}") # 주석 처리하여 출력 속도 개선

            # 💡 현재 게임의 태그 벡터 생성 (게임에 적용된 모든 TARGET_TAGS 반영)
            tag_vector = create_tag_vector(matching_tags)
            
            # 매칭된 각 태그에 대해 스크린샷을 저장합니다.
            for tag in matching_tags:
                genre_dir = genre_dirs[tag]
                
                if get_genre_file_count(genre_dir) >= MAX_FILES_PER_GENRE:
                    continue

                # 스크린샷 URL 추출 및 다운로드 작업 제출
            for shot in screenshots:
                screenshot_url = None
                if isinstance(shot, str):
                    screenshot_url = shot
                elif isinstance(shot, dict):
                    screenshot_url = shot.get('path_full')
                
                if screenshot_url:
                    original_filename = clean_filename(screenshot_url)
                    filename = f"{appid}_{original_filename}"
                    
                    # 💡 파일명-벡터 쌍을 CSV 데이터 맵에 기록 (파일명 중복 방지)
                    # 이 파일이 가진 최종 태그 벡터를 여기에 기록합니다.
                    csv_data_map[filename] = tag_vector 

                    # ❗️ 파일은 매칭된 모든 폴더에 저장됩니다.
                    for tag in matching_tags:
                        genre_dir = genre_dirs[tag]
                        
                        # 해당 폴더의 파일 수 확인 후 다운로드 제출
                        if get_genre_file_count(genre_dir) < MAX_FILES_PER_GENRE:
                            future = executor.submit(download_screenshot, screenshot_url, genre_dir, appid)
                            # 파일명 정보는 CSV 생성 시 필요하므로 함께 전달합니다.
                            future_to_info.append((future, filename))
                            
        # 🚀 모든 작업이 완료되기를 기다리고 결과를 처리
        downloaded_files: Set[str] = set() # 실제로 다운로드에 성공한 파일명만 추적
        
        for future, filename in concurrent.futures.as_completed(future_to_info):
            try:
                # download_screenshot의 결과는 (성공 여부, 파일명) 입니다.
                is_success, completed_filename = future.result() 
                
                if is_success:
                    # 다운로드 성공 시, 중복 다운로드와 상관없이 파일명만 성공 셋에 기록
                    if filename not in downloaded_files:
                        total_downloads += 1
                        
                    downloaded_files.add(filename)
                
                if total_downloads % 500 == 0 and total_downloads > 0:
                    print(f"--- 현재까지 총 다운로드 성공 파일 수: {total_downloads}개 ---")
                    
            except Exception as exc:
                print(f"다운로드 작업 중 예외 발생: {exc}")
                
        # 최종적으로 파일 제한을 다시 확인하고 관리 (옵션)
        for tag in TARGET_TAGS:
             manage_file_limit(genre_dirs[tag], MAX_FILES_PER_GENRE)



        # --------------------------------------------------------
        # 💡 CSV 파일 생성 및 저장 (csv_data_map과 downloaded_files 사용)
        # --------------------------------------------------------
        if csv_data_map:
            # 실제로 다운로드 성공한 파일만 필터링하여 CSV로 기록
            records = []
            for filename, vector in csv_data_map.items():
                if filename in downloaded_files:
                    records.append({'filename': filename, 'tag_vector': vector})
    
            if records:
                df = pd.DataFrame(records)
                
                # 벡터를 각 태그별 컬럼으로 분리
                vector_df = pd.DataFrame(df['tag_vector'].tolist(), columns=TARGET_TAGS)
                
                # 최종 데이터프레임 결합
                df_final = pd.concat([df[['filename']], vector_df], axis=1)
                
                # CSV 파일 저장 경로
                csv_output_path = os.path.join(BASE_DOWNLOAD_DIR, 'screenshot_tag_vectors_unique.csv')
                df_final.to_csv(csv_output_path, index=False, encoding='utf-8')
                
                print("-" * 50)
                print(f"✅ 태그 벡터 CSV 파일이 성공적으로 저장되었습니다.")
                print(f"파일명: {os.path.basename(csv_output_path)}")
                print(f"저장된 레코드 수: {len(df_final)}개 (실제 다운로드 성공 파일 기준)")
            else:
                 print("❌ 실제로 다운로드 성공한 파일이 없어 CSV로 저장할 레코드가 없습니다.")
                 
        else:
            print("❌ CSV로 저장할 태그 데이터가 없습니다.")

    print("-" * 50)
    print(f"✅ 모든 게임 처리가 완료되었습니다. 총 {total_downloads}개의 파일이 저장되었습니다.")
    print("-" * 50)

# ⚠️ 파일 경로를 실제 JSON 파일 이름으로 변경하세요!
FILE_PATH = 'games.json' 
process_game_data(FILE_PATH)
# Out:
# --------------------------------------------------
# 총 111452개의 게임을 처리합니다.
# 대상 태그: Fighting, Music
# 장르별 최대 파일 수: 12000개
# **동시 다운로드 스레드 수: 30개**
# --------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 266
#     264 # ⚠️ 파일 경로를 실제 JSON 파일 이름으로 변경하세요!
#     265 FILE_PATH = 'games.json'
# --> 266 process_game_data(FILE_PATH)
#
# Cell In[1], line 203, in process_game_data(file_path)
#     200 # 🚀 모든 작업이 완료되기를 기다리고 결과를 처리
#     201 downloaded_files: Set[str] = set() # 실제로 다운로드에 성공한 파일명만 추적
# --> 203 for future, filename in concurrent.futures.as_completed(future_to_info):
#     204     try:
#     205         # download_screenshot의 결과는 (성공 여부, 파일명) 입니다.
#     206         is_success, completed_filename = future.result()
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:222, in as_completed(fs, timeout)
#     220 fs = set(fs)
#     221 total_futures = len(fs)
# --> 222 with _AcquireFutures(fs):
#     223     finished = set(
#     224             f for f in fs
#     225             if f._state in [CANCELLED_AND_NOTIFIED, FINISHED])
#     226     pending = fs - finished
#
# File C:\ProgramData\anaconda3\Lib\concurrent\futures\_base.py:149, in _AcquireFutures.__enter__(self)
#     147 def __enter__(self):
#     148     for future in self.futures:
# --> 149         future._condition.acquire()
#
# AttributeError: 'tuple' object has no attribute '_condition'

# %%
import json
import requests
import os
from urllib.parse import urlparse
import time
import random
import concurrent.futures
import pandas as pd
from typing import Set, List, Dict, Tuple, Any

# --- 설정값 ---
FILE_PATH = 'games.json'  # ⚠️ JSON 파일 경로를 실제 파일 이름으로 변경하세요.
BASE_DOWNLOAD_DIR = r'F:\ML\dataset'

TARGET_GENRE = "Survival"
TARGET_MAX_FILES = 32000

TARGET_TAGS = [
    "Adventure", "Action", "RPG", "Strategy", "Simulation", "Sports", "Racing", 
    "Puzzle", "Sandbox", "Shooter", "Survival", "Fighting", "Music"
]
MAX_WORKERS = 30  # 💡 동시 다운로드 스레드 수 (네트워크 상황에 맞게 조정)
# --------------------
# ----------------

def clean_filename(url):
    """URL에서 안전한 파일 이름을 추출하고 확장자를 포함합니다."""
    path = urlparse(url).path
    filename = os.path.basename(path)
    # 쿼리 파라미터나 기타 불필요한 문자를 제거하고 안전하게 만듭니다.
    if '?' in filename:
        filename = filename.split('?')[0]
    return filename

def get_genre_file_count(genre_dir):
    """장르 폴더 내의 실제 파일 개수를 계산합니다."""
    if not os.path.exists(genre_dir):
        return 0
    # .DS_Store 같은 숨김 파일을 제외하고 파일 개수를 셉니다.
    return len([name for name in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, name)) and not name.startswith('.')])

def manage_file_limit(genre_dir, max_limit):
    """폴더의 파일 수가 최대 한도를 초과할 경우 파일을 랜덤하게 삭제합니다."""
    current_count = get_genre_file_count(genre_dir)
    if current_count > max_limit:
        files_to_delete = current_count - max_limit
        all_files = [f for f in os.listdir(genre_dir) if os.path.isfile(os.path.join(genre_dir, f)) and not f.startswith('.')]

        
        # 삭제할 파일을 랜덤하게 선택
        files_to_remove = random.sample(all_files, files_to_delete)
        
        print(f"[{os.path.basename(genre_dir)}] ❗️ 파일 초과: {current_count}개. {files_to_delete}개 삭제 중...")
        
        for file in files_to_remove:
            try:
                os.remove(os.path.join(genre_dir, file))
            except OSError as e:
                print(f"파일 삭제 오류: {e}")

def download_screenshot(url: str, genre_folder: str, appid: str) -> Tuple[bool, str]:
    """스크린샷을 다운로드하고 장르 폴더에 저장합니다. 성공 시 파일명을 반환합니다."""
    original_filename = clean_filename(url)
    filename = f"{appid}_{original_filename}"
    save_path = os.path.join(genre_folder, filename)

    if os.path.exists(save_path):
        # 💡 이미 파일이 존재하면 성공 (True)와 파일명을 함께 반환
        return True, filename

    try:
        response = requests.get(url, stream=True, timeout=10)
        response.raise_for_status()

        with open(save_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        # 💡 다운로드 성공 시 (True)와 파일명을 함께 반환
        return True, filename
    
    except requests.exceptions.RequestException as e:
        # 💡 다운로드 실패 시 (False)와 파일명을 함께 반환
        return False, filename

def create_tag_vector(matching_tags: Set[str]) -> List[int]:
    """
    매칭되는 태그를 TARGET_TAGS 순서에 따른 원-핫 벡터로 변환합니다.
    """
    vector = [0] * len(TARGET_TAGS)
    for i, target_tag in enumerate(TARGET_TAGS):
        if target_tag in matching_tags:
            vector[i] = 1
    return vector

# (download_screenshot, clean_filename, get_genre_file_count, manage_file_limit 함수는 그대로 유지)


def process_game_data(file_path):
    """JSON 파일을 읽고 지정된 태그별로 스크린샷을 병렬로 다운로드합니다."""
    # ... (파일 로드 및 초기 설정 부분은 그대로 유지) ...
    """JSON 파일을 읽고 지정된 태그별로 스크린샷을 다운로드합니다."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"❌ 오류: 파일을 찾을 수 없습니다. 경로를 확인해 주세요: {file_path}")
        return
    except json.JSONDecodeError:
        print("❌ 오류: JSON 파일 형식이 올바르지 않습니다.")
        return

    if TARGET_GENRE not in TARGET_TAGS:
        print(f"❌ 오류: TARGET_GENRE '{TARGET_GENRE}'가 TARGET_TAGS에 없습니다. 설정을 확인하세요.")
        return
    
    # 기본 다운로드 디렉토리 생성 및 장르별 폴더 관리 (기존 코드 유지)
    # 단일 장르 폴더 설정
    genre_dir = os.path.join(BASE_DOWNLOAD_DIR, TARGET_GENRE)
    os.makedirs(genre_dir, exist_ok=True)
    manage_file_limit(genre_dir, TARGET_MAX_FILES)
    
    current_count = get_genre_file_count(genre_dir)

    game_list = data.values() if isinstance(data, dict) else data
    total_downloads = 0
    
    csv_data_map: Dict[str, List[int]] = {}
    
    print("-" * 50)
    print(f"단일 장르 크롤링 시작: {TARGET_GENRE}")
    print(f"목표 파일 수: {TARGET_MAX_FILES}개 (현재 {current_count}개)")
    print("-" * 50)

    # 🚀 ThreadPoolExecutor를 사용하여 병렬 처리 시작
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        
        future_to_filename: Dict[concurrent.futures.Future, str] = {}
        
        for appid, game in data.items():
            if current_count >= TARGET_MAX_FILES:
                break # 전체 게임 탐색 중 목표 수에 도달하면 중단

            if not isinstance(game, dict):
                continue
                
            # 태그 처리 로직
            tags_data = game.get('tags')
            if isinstance(tags_data, dict):
                game_tags = set(tags_data.keys())
            elif isinstance(tags_data, list):
                game_tags = set(tags_data)
            else:
                continue
                
            # ❗️ 단일 장르 매칭 확인
            if TARGET_GENRE not in game_tags:
                continue
                
            # 💡 전체 13개 태그와의 교집합으로 벡터 생성 (CSV 기록용)
            matching_tags = game_tags.intersection(TARGET_TAGS)
            tag_vector = create_tag_vector(matching_tags)

            screenshots = game.get('screenshots', [])
            if not screenshots:
                continue
                
            # 스크린샷 URL 추출 및 다운로드 작업 제출
            for shot in screenshots:
                if current_count >= TARGET_MAX_FILES:
                    break

                screenshot_url = None
                if isinstance(shot, str):
                    screenshot_url = shot
                elif isinstance(shot, dict):
                    screenshot_url = shot.get('path_full')
                
                if screenshot_url:
                    original_filename = clean_filename(screenshot_url)
                    filename = f"{appid}_{original_filename}"
                    
                    # 💡 파일명-벡터 쌍을 CSV 데이터 맵에 기록 (파일명 중복 방지)
                    csv_data_map[filename] = tag_vector 
    
                    # ❗️ 단일 장르 폴더에만 다운로드 작업 제출
                    future = executor.submit(download_screenshot, screenshot_url, genre_dir, appid)
                    
                    # 💡 수정: Future 객체와 파일명을 맵핑 딕셔너리에 추가
                    future_to_filename[future] = filename
                    
        # 🚀 모든 작업이 완료되기를 기다리고 결과를 처리
        downloaded_files: Set[str] = set() # 실제로 다운로드에 성공한 파일명만 추적
        
        # 💡 수정: future_to_filename.keys()를 사용하여 Future 객체만 전달
        for future in concurrent.futures.as_completed(future_to_filename.keys()):
            # 💡 수정: Future 객체로 파일명을 찾습니다.
            filename = future_to_filename[future] 
            
            try:
                # download_screenshot의 결과는 (성공 여부, 파일명) 입니다.
                is_success, completed_filename = future.result() 
                
                if is_success:
                    if filename not in downloaded_files:
                        total_downloads += 1
                        
                    downloaded_files.add(filename)
                
                if total_downloads % 100 == 0 and total_downloads > 0:
                    print(f"--- 현재까지 총 다운로드 성공 파일 수: {total_downloads}개 ---")
                    
            except Exception as exc:
                print(f"다운로드 작업 중 예외 발생: {exc}")
                
        # 최종적으로 파일 제한을 다시 확인하고 관리 (이전에 초과된 파일 정리)
        manage_file_limit(genre_dir, TARGET_MAX_FILES)

    # --------------------------------------------------------
    # 💡 CSV 파일 생성 및 저장
    # --------------------------------------------------------
    if csv_data_map:
        records = []
        # ❗️ 실제로 다운로드 성공한 파일만 필터링하여 CSV로 기록
        for filename, vector in csv_data_map.items():
            if filename in downloaded_files:
                records.append({'filename': filename, 'tag_vector': vector})

        if records:
            df = pd.DataFrame(records)
            vector_df = pd.DataFrame(df['tag_vector'].tolist(), columns=TARGET_TAGS)
            df_final = pd.concat([df[['filename']], vector_df], axis=1)
            
            # CSV 파일 저장 경로
            # 💡 수정된 부분: 파일명에 TARGET_GENRE를 포함시킵니다.
            csv_filename = f'screenshot_tag_vectors_{TARGET_GENRE}.csv'
            csv_output_path = os.path.join(BASE_DOWNLOAD_DIR, csv_filename)
            
            df_final.to_csv(csv_output_path, index=False, encoding='utf-8')
            
            print("-" * 50)
            print(f"✅ 태그 벡터 CSV 파일이 성공적으로 저장되었습니다.")
            print(f"저장된 레코드 수: {len(df_final)}개 (실제 다운로드 성공 파일 기준)")
        else:
             print("❌ 실제로 다운로드 성공한 파일이 없어 CSV로 저장할 레코드가 없습니다.")
             
    print("-" * 50)
    print(f"✅ 모든 처리가 완료되었습니다. 총 {total_downloads}개의 파일이 '{TARGET_GENRE}' 폴더에 저장되었습니다.")
    print("-" * 50)

process_game_data(FILE_PATH)
# Out:
# --------------------------------------------------
# 단일 장르 크롤링 시작: Survival
# 목표 파일 수: 32000개 (현재 0개)
# --------------------------------------------------
# --- 현재까지 총 다운로드 성공 파일 수: 100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 1900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 2900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 3900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 4900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 5900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 6900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 7900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 8900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 9900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 10900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 11900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 12900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 13900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 14900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 15900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 16900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 17900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 18900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 19900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 20900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 21900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 22900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 23900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 24900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 25900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 26900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 27900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 28900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 29900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 30900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 31900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 32900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 33900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 34900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 35900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 36900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 37900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 38900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 39900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 40900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 41900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 42900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 43900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 44900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 45900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 46900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 47900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 48900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 49900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 50900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 51900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 52900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 53900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 54900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 55900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 56900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 57900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 58900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59300개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59400개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59500개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59600개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59700개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59800개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 59900개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 60000개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 60100개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 60200개 ---
# --- 현재까지 총 다운로드 성공 파일 수: 60300개 ---
# [Survival] ❗️ 파일 초과: 60314개. 28314개 삭제 중...
# --------------------------------------------------
# ✅ 태그 벡터 CSV 파일이 성공적으로 저장되었습니다.
# 저장된 레코드 수: 60314개 (실제 다운로드 성공 파일 기준)
# --------------------------------------------------
# ✅ 모든 처리가 완료되었습니다. 총 60314개의 파일이 'Survival' 폴더에 저장되었습니다.
# --------------------------------------------------

# %%
#전처리 224*224

from PIL import Image, ImageFile
import os
import glob
import concurrent.futures
from typing import Tuple, List

# 💡 이 설정값들을 사용자의 환경에 맞게 반드시 수정하세요!
# -------------------------------------------------------------
BASE_DOWNLOAD_DIR = r'F:\ML\dataset'      # 👈 원본 장르 폴더들이 있는 기본 경로
RESIZED_DIR_NAME = 'Processed_224x224' # 👈 전처리된 파일들을 저장할 새 폴더 이름
TARGET_SIZE = (224, 224)              # 👈 목표 해상도 (224x224)
TARGET_TAGS: List[str] = [
    "Adventure", "Action", "RPG", "Strategy", "Simulation", "Sports", "Racing", 
    "Puzzle", "Sandbox", "Shooter", "Survival", "Fighting", "Music"
]
# -------------------------------------------------------------
# 파일이 너무 크거나 손상된 경우를 대비하여 파일 로드 한도 확장
ImageFile.LOAD_TRUNCATED_IMAGES = True


# 💡 병렬 처리 설정
MAX_PROCESSES = 4 # 사용 가능한 CPU 코어 수 사용 (최소 4개)


# 💡 새로운 헬퍼 함수: 단일 이미지 처리 및 저장
def process_single_image(input_path: str, output_path: str, target_size: Tuple[int, int]) -> bool:
    """단일 이미지를 전처리하고 저장하며 성공 여부를 반환합니다."""
    try:
        # 파일이 이미 전처리되어 있으면 건너뜁니다.
        if os.path.exists(output_path):
            return True

        # 이미지 로드 및 RGB 변환
        img = Image.open(input_path).convert('RGB')
        
        # 패딩을 적용하여 리사이징 (pad_to_square 함수는 이전 정의 사용)
        resized_img = pad_to_square(img, target_size)
        
        # JPEG 포맷으로 저장
        resized_img.save(output_path, format='JPEG', quality=90)
        
        return True
    
    except Exception as e:
        # print(f"  [오류] 파일 처리 실패 ({os.path.basename(input_path)}): {e}")
        return False

def pad_to_square(img: Image.Image, target_size: Tuple[int, int]) -> Image.Image:
    """종횡비를 유지하면서 이미지를 정사각형으로 만들고 빈 공간을 검은색(0,0,0)으로 채웁니다."""
    
    width, height = img.size
    target_w, target_h = target_size
    
    # 목표 크기 중 작은 쪽을 기준으로 비율 계산 (축소 비율 계산)
    ratio = min(target_w / width, target_h / height)
    new_w = int(width * ratio)
    new_h = int(height * ratio)

    # 1. 축소 리사이징
    # Image.Resampling.LANCZOS는 고품질 축소에 사용됩니다.
    img = img.resize((new_w, new_h), Image.Resampling.LANCZOS) 

    # 2. 목표 크기의 검은색 캔버스 생성
    new_img = Image.new('RGB', target_size, (0, 0, 0)) 
    
    # 3. 리사이징된 이미지를 캔버스 중앙에 붙여넣기
    left = (target_w - new_w) // 2
    top = (target_h - new_h) // 2
    new_img.paste(img, (left, top))
    
    return new_img


def preprocess_images_parallel():
    """
    원본 경로의 모든 장르 폴더를 순회하며 224x224로 병렬 전처리 후 새 경로에 저장합니다.
    """
    output_base_dir = os.path.join(BASE_DOWNLOAD_DIR, RESIZED_DIR_NAME)
    os.makedirs(output_base_dir, exist_ok=True)
    
    total_processed = 0
    all_tasks = [] # 모든 이미지 처리 작업을 담을 리스트

    print(f"이미지 전처리 시작. 병렬 프로세스: {MAX_PROCESSES}개")
    print("-" * 50)

    # 1. 모든 작업(Task) 수집
    for tag in TARGET_TAGS:
        input_genre_dir = os.path.join(BASE_DOWNLOAD_DIR, tag)
        output_genre_dir = os.path.join(output_base_dir, tag)
        
        if not os.path.isdir(input_genre_dir):
            continue
            
        os.makedirs(output_genre_dir, exist_ok=True)
        
        image_files = glob.glob(os.path.join(input_genre_dir, '*.[pj][np]g'))
        
        for input_path in image_files:
            filename = os.path.basename(input_path)
            output_path = os.path.join(output_genre_dir, filename)
            
            # (input_path, output_path, TARGET_SIZE) 튜플을 작업 리스트에 추가
            all_tasks.append((input_path, output_path, TARGET_SIZE))

    print(f"총 {len(all_tasks)}개의 전처리 작업을 등록했습니다. 처리 시작...")
    
    # 2. ProcessPoolExecutor를 사용하여 병렬 처리 실행
    with concurrent.futures.ProcessPoolExecutor(max_workers=MAX_PROCESSES) as executor:
        
        # executor.map을 사용하여 모든 작업을 병렬로 실행
        results = executor.map(process_single_image, 
                               [t[0] for t in all_tasks], # input_path 리스트
                               [t[1] for t in all_tasks], # output_path 리스트
                               [t[2] for t in all_tasks]) # target_size 리스트 (전부 동일)
        
        # 3. 결과 집계
        for success in results:
            if success:
                total_processed += 1
            
            # 진행 상황 출력 (10000개마다)
            if total_processed % 10000 == 0 and total_processed > 0:
                print(f"--- {total_processed}개 이미지 처리 완료 ---")


    print("-" * 50)
    print(f"✅ 모든 전처리가 완료되었습니다. 총 {total_processed}개의 파일이 저장되었습니다.")
    print(f"최종 데이터 경로: {output_base_dir}")
    print("-" * 50)

# 전처리 함수 실행
if __name__ == "__main__":
    preprocess_images_parallel()
# Out:
# 이미지 전처리 시작. 병렬 프로세스: 4개
# --------------------------------------------------
# 총 442341개의 전처리 작업을 등록했습니다. 처리 시작...
